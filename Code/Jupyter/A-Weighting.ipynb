# %%
import octafilt3r.plot as o3p
import octafilt3r.weightings as o3w
fs = 48000
sos = o3w._A_sos(fs)
print(sos)
o3p._display_filt(sos, fs, "A-weighting")

# for stage in sos:
#     for coeff in stage:
#         print(f'{coeff:.12f}')
# Out:
# [[ 0.2343006   0.46860119  0.2343006   1.         -0.22455845  0.01260662]
#  [ 1.         -2.          1.          1.         -1.89387049  0.89515977]
#  [ 1.         -2.          1.          1.         -1.99461446  0.99462171]]

# %% [markdown]
# # Feature Extraction
#
# Since the filters have been explored, the data displayed in spectrograms can now be written to `csv`-files for later training of the NN. The amount of data per soundfile is calculated with the following formula:
#
# ```
# size_in_b = n_frames * n_bands * sizeof(float32)
# ```
#
# This is one of the major strenghts of this method: instead of storing `512` bins `1024` times per second, the octave bank only creates `31` bins `24` times a second.

# %%
import os
from octafilt3r import filter as o3f
from octafilt3r import weightings as o3w
import librosa as lr
import numpy as np
import pipeline.config as conf

# %%
param_dict = conf.open_params()

# %%
# def spec(y, sr):
#     X = lr.stft(y)
#     Xdb = lr.power_to_db(abs(X)**2, ref = 1)
#     plt.figure(figsize=(14, 5))
#     lr.display.specshow(Xdb, sr=sr, x_axis='time', y_axis='log', cmap = 'rainbow')
#     plt.colorbar()    

# y, sr = lr.load("demo_data/whitenoise.wav", sr=param_dict["fs"], mono=True, duration=param_dict["max_dur"])
# spec(y, sr)
# y_a = A_weight(y, sr)
# spec(y_a, sr)

# %%
files_ignored = 0
tot_cnt = 0

df = []
labels = []
leq = []
for class_ in os.listdir(param_dict["source_dir"]):
    cnt = 1
    for filename in os.listdir(f'{param_dict["source_dir"]}{class_}'):

        print(f'Currently extracting features in "{class_}" from {filename} (# {cnt})')

        wav = f'{param_dict["source_dir"]}{class_}/{filename}'
        y, sr = lr.load(wav, sr=param_dict["fs"], mono=True, duration=param_dict["max_dur"])

        y = o3w.A_weight(y, sr)

        wins = int(len(y)/param_dict["window_size"])
        if wins == 0:
            files_ignored += 1
            print('*ignored, file under 1 second long*')
            continue    # skip files which are shorter than 1s

        # obtain features of whole file
        feats, fcs, lq = o3f.rolling_oct_bank(y, 
                                        param_dict["fs"], 
                                        ratio=param_dict["oct_bw_ratio"], 
                                        fmax=param_dict["fmax"], 
                                        fmin=param_dict["fmin"], 
                                        frame_size=param_dict["frame_size"], 
                                        n_decimations=param_dict["dec_stages"])

        print(f'\tSplitting "{filename}" into {wins} 1-second part(s)')
        for win in range(wins):    # ignore parts of file which is not in a full window
            cur_feats = feats[param_dict["fps"] * win:param_dict["fps"] * (win + 1)]
            df.append(cur_feats)
            labels.append(class_)
            leq.append(lq[win])
        cnt += 1

    tot_cnt += cnt


df = np.dstack(df)
df = np.transpose(df, (2, 0, 1))

df_2d = df.reshape(df.shape[0], -1)
np.savetxt(param_dict["extr_txt_fp"], df_2d)
with open(param_dict["label_txt_fp"], "w") as f:
    for i in labels:
        f.writelines(i + '\n')
with open(param_dict["leq_txt_fp"], "w") as f:
    for i in leq:
        f.writelines(str(i) + '\n')        


print(f'----- done. -----\nTotal file count: {tot_cnt}\nFiles ignored: {files_ignored}\nExtracted {len(df)} windows from {tot_cnt-files_ignored} Files')
print(f'Shape of dataframe: {df.shape}')
print(f'Shape of labels: {np.shape(labels)}')
print(f'Shape of LEQs: {np.shape(leq)}')
# Out:
# Currently extracting features in "multi" from audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 1)
# 	Splitting "audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 2)
# 	Splitting "audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 3)
# 	Splitting "audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from fade1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 4)
# 	Splitting "fade1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from fade1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 5)
# 	Splitting "fade1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from fade1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 6)
# 	Splitting "fade1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from fade1_fade1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 7)
# 	Splitting "fade1_fade1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from fade1_fade1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 8)
# 	Splitting "fade1_fade1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from fade1_fade1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 9)
# 	Splitting "fade1_fade1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from fade1_psd1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 10)
# 	Splitting "fade1_psd1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from fade1_psd1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 11)
# 	Splitting "fade1_psd1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from fade1_psd1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 12)
# 	Splitting "fade1_psd1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from fade1_psd2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 13)
# 	Splitting "fade1_psd2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from fade1_psd2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 14)
# 	Splitting "fade1_psd2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from fade1_psd2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 15)
# 	Splitting "fade1_psd2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from fade1_psu1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 16)
# 	Splitting "fade1_psu1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from fade1_psu1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 17)
# 	Splitting "fade1_psu1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from fade1_psu1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 18)
# 	Splitting "fade1_psu1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from fade1_psu2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 19)
# 	Splitting "fade1_psu2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from fade1_psu2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 20)
# 	Splitting "fade1_psu2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from fade1_psu2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 21)
# 	Splitting "fade1_psu2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 22)
# 	Splitting "psd1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 23)
# 	Splitting "psd1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 24)
# 	Splitting "psd1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd1_fade1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 25)
# 	Splitting "psd1_fade1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd1_fade1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 26)
# 	Splitting "psd1_fade1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd1_fade1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 27)
# 	Splitting "psd1_fade1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd1_psd1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 28)
# 	Splitting "psd1_psd1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd1_psd1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 29)
# 	Splitting "psd1_psd1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd1_psd1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 30)
# 	Splitting "psd1_psd1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd1_psd2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 31)
# 	Splitting "psd1_psd2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd1_psd2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 32)
# 	Splitting "psd1_psd2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd1_psd2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 33)
# 	Splitting "psd1_psd2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd1_psu1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 34)
# 	Splitting "psd1_psu1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd1_psu1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 35)
# 	Splitting "psd1_psu1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd1_psu1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 36)
# 	Splitting "psd1_psu1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd1_psu2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 37)
# 	Splitting "psd1_psu2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd1_psu2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 38)
# 	Splitting "psd1_psu2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd1_psu2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 39)
# 	Splitting "psd1_psu2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 40)
# 	Splitting "psd2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 41)
# 	Splitting "psd2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 42)
# 	Splitting "psd2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd2_fade1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 43)
# 	Splitting "psd2_fade1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd2_fade1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 44)
# 	Splitting "psd2_fade1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd2_fade1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 45)
# 	Splitting "psd2_fade1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd2_psd1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 46)
# 	Splitting "psd2_psd1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd2_psd1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 47)
# 	Splitting "psd2_psd1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd2_psd1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 48)
# 	Splitting "psd2_psd1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd2_psd2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 49)
# 	Splitting "psd2_psd2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd2_psd2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 50)
# 	Splitting "psd2_psd2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd2_psd2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 51)
# 	Splitting "psd2_psd2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd2_psu1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 52)
# 	Splitting "psd2_psu1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd2_psu1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 53)
# 	Splitting "psd2_psu1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd2_psu1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 54)
# 	Splitting "psd2_psu1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd2_psu2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 55)
# 	Splitting "psd2_psu2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd2_psu2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 56)
# 	Splitting "psd2_psu2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psd2_psu2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 57)
# 	Splitting "psd2_psu2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 58)
# 	Splitting "psu1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 59)
# 	Splitting "psu1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 60)
# 	Splitting "psu1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu1_fade1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 61)
# 	Splitting "psu1_fade1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu1_fade1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 62)
# 	Splitting "psu1_fade1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu1_fade1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 63)
# 	Splitting "psu1_fade1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu1_psd1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 64)
# 	Splitting "psu1_psd1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu1_psd1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 65)
# 	Splitting "psu1_psd1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu1_psd1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 66)
# 	Splitting "psu1_psd1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu1_psd2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 67)
# 	Splitting "psu1_psd2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu1_psd2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 68)
# 	Splitting "psu1_psd2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu1_psd2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 69)
# 	Splitting "psu1_psd2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu1_psu1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 70)
# 	Splitting "psu1_psu1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu1_psu1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 71)
# 	Splitting "psu1_psu1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu1_psu1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 72)
# 	Splitting "psu1_psu1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu1_psu2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 73)
# 	Splitting "psu1_psu2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu1_psu2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 74)
# 	Splitting "psu1_psu2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu1_psu2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 75)
# 	Splitting "psu1_psu2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 76)
# 	Splitting "psu2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 77)
# 	Splitting "psu2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 78)
# 	Splitting "psu2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu2_fade1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 79)
# 	Splitting "psu2_fade1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu2_fade1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 80)
# 	Splitting "psu2_fade1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu2_fade1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 81)
# 	Splitting "psu2_fade1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu2_psd1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 82)
# 	Splitting "psu2_psd1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu2_psd1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 83)
# 	Splitting "psu2_psd1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu2_psd1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 84)
# 	Splitting "psu2_psd1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu2_psd2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 85)
# 	Splitting "psu2_psd2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu2_psd2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 86)
# 	Splitting "psu2_psd2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu2_psd2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 87)
# 	Splitting "psu2_psd2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu2_psu1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 88)
# 	Splitting "psu2_psu1_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu2_psu1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 89)
# 	Splitting "psu2_psu1_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu2_psu1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 90)
# 	Splitting "psu2_psu1_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu2_psu2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav (# 91)
# 	Splitting "psu2_psu2_audiocheck.net_100Hz_-5dBFS_1000Hz_-17dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu2_psu2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav (# 92)
# 	Splitting "psu2_psu2_audiocheck.net_600Hz_-5dBFS_1200Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "multi" from psu2_psu2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav (# 93)
# 	Splitting "psu2_psu2_audiocheck.net_600Hz_-5dBFS_900Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from fade1_fade1_pinknoise.wav (# 1)
# 	Splitting "fade1_fade1_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from fade1_fade1_whitenoise.wav (# 2)
# 	Splitting "fade1_fade1_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from fade1_pinknoise.wav (# 3)
# 	Splitting "fade1_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from fade1_psd1_pinknoise.wav (# 4)
# 	Splitting "fade1_psd1_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from fade1_psd1_whitenoise.wav (# 5)
# 	Splitting "fade1_psd1_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from fade1_psd2_pinknoise.wav (# 6)
# 	Splitting "fade1_psd2_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from fade1_psd2_whitenoise.wav (# 7)
# 	Splitting "fade1_psd2_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from fade1_psu1_pinknoise.wav (# 8)
# 	Splitting "fade1_psu1_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from fade1_psu1_whitenoise.wav (# 9)
# 	Splitting "fade1_psu1_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from fade1_psu2_pinknoise.wav (# 10)
# 	Splitting "fade1_psu2_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from fade1_psu2_whitenoise.wav (# 11)
# 	Splitting "fade1_psu2_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from fade1_whitenoise.wav (# 12)
# 	Splitting "fade1_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from pinknoise.wav (# 13)
# 	Splitting "pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd1_fade1_pinknoise.wav (# 14)
# 	Splitting "psd1_fade1_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd1_fade1_whitenoise.wav (# 15)
# 	Splitting "psd1_fade1_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd1_pinknoise.wav (# 16)
# 	Splitting "psd1_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd1_psd1_pinknoise.wav (# 17)
# 	Splitting "psd1_psd1_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd1_psd1_whitenoise.wav (# 18)
# 	Splitting "psd1_psd1_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd1_psd2_pinknoise.wav (# 19)
# 	Splitting "psd1_psd2_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd1_psd2_whitenoise.wav (# 20)
# 	Splitting "psd1_psd2_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd1_psu1_pinknoise.wav (# 21)
# 	Splitting "psd1_psu1_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd1_psu1_whitenoise.wav (# 22)
# 	Splitting "psd1_psu1_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd1_psu2_pinknoise.wav (# 23)
# 	Splitting "psd1_psu2_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd1_psu2_whitenoise.wav (# 24)
# 	Splitting "psd1_psu2_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd1_whitenoise.wav (# 25)
# 	Splitting "psd1_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd2_fade1_pinknoise.wav (# 26)
# 	Splitting "psd2_fade1_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd2_fade1_whitenoise.wav (# 27)
# 	Splitting "psd2_fade1_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd2_pinknoise.wav (# 28)
# 	Splitting "psd2_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd2_psd1_pinknoise.wav (# 29)
# 	Splitting "psd2_psd1_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd2_psd1_whitenoise.wav (# 30)
# 	Splitting "psd2_psd1_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd2_psd2_pinknoise.wav (# 31)
# 	Splitting "psd2_psd2_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd2_psd2_whitenoise.wav (# 32)
# 	Splitting "psd2_psd2_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd2_psu1_pinknoise.wav (# 33)
# 	Splitting "psd2_psu1_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd2_psu1_whitenoise.wav (# 34)
# 	Splitting "psd2_psu1_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd2_psu2_pinknoise.wav (# 35)
# 	Splitting "psd2_psu2_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd2_psu2_whitenoise.wav (# 36)
# 	Splitting "psd2_psu2_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psd2_whitenoise.wav (# 37)
# 	Splitting "psd2_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu1_fade1_pinknoise.wav (# 38)
# 	Splitting "psu1_fade1_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu1_fade1_whitenoise.wav (# 39)
# 	Splitting "psu1_fade1_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu1_pinknoise.wav (# 40)
# 	Splitting "psu1_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu1_psd1_pinknoise.wav (# 41)
# 	Splitting "psu1_psd1_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu1_psd1_whitenoise.wav (# 42)
# 	Splitting "psu1_psd1_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu1_psd2_pinknoise.wav (# 43)
# 	Splitting "psu1_psd2_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu1_psd2_whitenoise.wav (# 44)
# 	Splitting "psu1_psd2_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu1_psu1_pinknoise.wav (# 45)
# 	Splitting "psu1_psu1_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu1_psu1_whitenoise.wav (# 46)
# 	Splitting "psu1_psu1_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu1_psu2_pinknoise.wav (# 47)
# 	Splitting "psu1_psu2_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu1_psu2_whitenoise.wav (# 48)
# 	Splitting "psu1_psu2_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu1_whitenoise.wav (# 49)
# 	Splitting "psu1_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu2_fade1_pinknoise.wav (# 50)
# 	Splitting "psu2_fade1_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu2_fade1_whitenoise.wav (# 51)
# 	Splitting "psu2_fade1_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu2_pinknoise.wav (# 52)
# 	Splitting "psu2_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu2_psd1_pinknoise.wav (# 53)
# 	Splitting "psu2_psd1_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu2_psd1_whitenoise.wav (# 54)
# 	Splitting "psu2_psd1_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu2_psd2_pinknoise.wav (# 55)
# 	Splitting "psu2_psd2_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu2_psd2_whitenoise.wav (# 56)
# 	Splitting "psu2_psd2_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu2_psu1_pinknoise.wav (# 57)
# 	Splitting "psu2_psu1_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu2_psu1_whitenoise.wav (# 58)
# 	Splitting "psu2_psu1_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu2_psu2_pinknoise.wav (# 59)
# 	Splitting "psu2_psu2_pinknoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu2_psu2_whitenoise.wav (# 60)
# 	Splitting "psu2_psu2_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from psu2_whitenoise.wav (# 61)
# 	Splitting "psu2_whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "noise" from whitenoise.wav (# 62)
# 	Splitting "whitenoise.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 1)
# 	Splitting "audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 2)
# 	Splitting "audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from audiocheck.net_sin_100Hz_-3dBFS_10s_.wav (# 3)
# 	Splitting "audiocheck.net_sin_100Hz_-3dBFS_10s_.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from fade1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 4)
# 	Splitting "fade1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from fade1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 5)
# 	Splitting "fade1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from fade1_fade1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 6)
# 	Splitting "fade1_fade1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from fade1_fade1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 7)
# 	Splitting "fade1_fade1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from fade1_fade1_sine1k.wav (# 8)
# 	Splitting "fade1_fade1_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from fade1_psd1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 9)
# 	Splitting "fade1_psd1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from fade1_psd1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 10)
# 	Splitting "fade1_psd1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from fade1_psd1_sine1k.wav (# 11)
# 	Splitting "fade1_psd1_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from fade1_psd2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 12)
# 	Splitting "fade1_psd2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from fade1_psd2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 13)
# 	Splitting "fade1_psd2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from fade1_psd2_sine1k.wav (# 14)
# 	Splitting "fade1_psd2_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from fade1_psu1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 15)
# 	Splitting "fade1_psu1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from fade1_psu1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 16)
# 	Splitting "fade1_psu1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from fade1_psu1_sine1k.wav (# 17)
# 	Splitting "fade1_psu1_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from fade1_psu2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 18)
# 	Splitting "fade1_psu2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from fade1_psu2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 19)
# 	Splitting "fade1_psu2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from fade1_psu2_sine1k.wav (# 20)
# 	Splitting "fade1_psu2_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from fade1_sine1k.wav (# 21)
# 	Splitting "fade1_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 22)
# 	Splitting "psd1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 23)
# 	Splitting "psd1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd1_fade1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 24)
# 	Splitting "psd1_fade1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd1_fade1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 25)
# 	Splitting "psd1_fade1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd1_fade1_sine1k.wav (# 26)
# 	Splitting "psd1_fade1_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd1_psd1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 27)
# 	Splitting "psd1_psd1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd1_psd1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 28)
# 	Splitting "psd1_psd1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd1_psd1_sine1k.wav (# 29)
# 	Splitting "psd1_psd1_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd1_psd2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 30)
# 	Splitting "psd1_psd2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd1_psd2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 31)
# 	Splitting "psd1_psd2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd1_psd2_sine1k.wav (# 32)
# 	Splitting "psd1_psd2_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd1_psu1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 33)
# 	Splitting "psd1_psu1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd1_psu1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 34)
# 	Splitting "psd1_psu1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd1_psu1_sine1k.wav (# 35)
# 	Splitting "psd1_psu1_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd1_psu2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 36)
# 	Splitting "psd1_psu2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd1_psu2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 37)
# 	Splitting "psd1_psu2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd1_psu2_sine1k.wav (# 38)
# 	Splitting "psd1_psu2_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd1_sine1k.wav (# 39)
# 	Splitting "psd1_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 40)
# 	Splitting "psd2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 41)
# 	Splitting "psd2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd2_fade1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 42)
# 	Splitting "psd2_fade1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd2_fade1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 43)
# 	Splitting "psd2_fade1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd2_fade1_sine1k.wav (# 44)
# 	Splitting "psd2_fade1_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd2_psd1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 45)
# 	Splitting "psd2_psd1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd2_psd1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 46)
# 	Splitting "psd2_psd1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd2_psd1_sine1k.wav (# 47)
# 	Splitting "psd2_psd1_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd2_psd2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 48)
# 	Splitting "psd2_psd2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd2_psd2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 49)
# 	Splitting "psd2_psd2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd2_psd2_sine1k.wav (# 50)
# 	Splitting "psd2_psd2_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd2_psu1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 51)
# 	Splitting "psd2_psu1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd2_psu1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 52)
# 	Splitting "psd2_psu1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd2_psu1_sine1k.wav (# 53)
# 	Splitting "psd2_psu1_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd2_psu2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 54)
# 	Splitting "psd2_psu2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd2_psu2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 55)
# 	Splitting "psd2_psu2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd2_psu2_sine1k.wav (# 56)
# 	Splitting "psd2_psu2_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psd2_sine1k.wav (# 57)
# 	Splitting "psd2_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 58)
# 	Splitting "psu1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 59)
# 	Splitting "psu1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu1_fade1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 60)
# 	Splitting "psu1_fade1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu1_fade1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 61)
# 	Splitting "psu1_fade1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu1_fade1_sine1k.wav (# 62)
# 	Splitting "psu1_fade1_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu1_psd1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 63)
# 	Splitting "psu1_psd1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu1_psd1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 64)
# 	Splitting "psu1_psd1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu1_psd1_sine1k.wav (# 65)
# 	Splitting "psu1_psd1_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu1_psd2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 66)
# 	Splitting "psu1_psd2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu1_psd2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 67)
# 	Splitting "psu1_psd2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu1_psd2_sine1k.wav (# 68)
# 	Splitting "psu1_psd2_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu1_psu1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 69)
# 	Splitting "psu1_psu1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu1_psu1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 70)
# 	Splitting "psu1_psu1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu1_psu1_sine1k.wav (# 71)
# 	Splitting "psu1_psu1_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu1_psu2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 72)
# 	Splitting "psu1_psu2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu1_psu2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 73)
# 	Splitting "psu1_psu2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu1_psu2_sine1k.wav (# 74)
# 	Splitting "psu1_psu2_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu1_sine1k.wav (# 75)
# 	Splitting "psu1_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 76)
# 	Splitting "psu2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 77)
# 	Splitting "psu2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu2_fade1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 78)
# 	Splitting "psu2_fade1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu2_fade1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 79)
# 	Splitting "psu2_fade1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu2_fade1_sine1k.wav (# 80)
# 	Splitting "psu2_fade1_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu2_psd1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 81)
# 	Splitting "psu2_psd1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu2_psd1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 82)
# 	Splitting "psu2_psd1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu2_psd1_sine1k.wav (# 83)
# 	Splitting "psu2_psd1_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu2_psd2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 84)
# 	Splitting "psu2_psd2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu2_psd2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 85)
# 	Splitting "psu2_psd2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu2_psd2_sine1k.wav (# 86)
# 	Splitting "psu2_psd2_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu2_psu1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 87)
# 	Splitting "psu2_psu1_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu2_psu1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 88)
# 	Splitting "psu2_psu1_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu2_psu1_sine1k.wav (# 89)
# 	Splitting "psu2_psu1_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu2_psu2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav (# 90)
# 	Splitting "psu2_psu2_audiocheck.net_sin_10000Hz_-10dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu2_psu2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav (# 91)
# 	Splitting "psu2_psu2_audiocheck.net_sin_100Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu2_psu2_sine1k.wav (# 92)
# 	Splitting "psu2_psu2_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sine" from psu2_sine1k.wav (# 93)
# 	Splitting "psu2_sine1k.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 1)
# 	Splitting "audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 2)
# 	Splitting "audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 3)
# 	Splitting "audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from fade1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 4)
# 	Splitting "fade1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from fade1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 5)
# 	Splitting "fade1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from fade1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 6)
# 	Splitting "fade1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from fade1_fade1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 7)
# 	Splitting "fade1_fade1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from fade1_fade1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 8)
# 	Splitting "fade1_fade1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from fade1_fade1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 9)
# 	Splitting "fade1_fade1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from fade1_psd1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 10)
# 	Splitting "fade1_psd1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from fade1_psd1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 11)
# 	Splitting "fade1_psd1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from fade1_psd1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 12)
# 	Splitting "fade1_psd1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from fade1_psd2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 13)
# 	Splitting "fade1_psd2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from fade1_psd2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 14)
# 	Splitting "fade1_psd2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from fade1_psd2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 15)
# 	Splitting "fade1_psd2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from fade1_psu1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 16)
# 	Splitting "fade1_psu1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from fade1_psu1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 17)
# 	Splitting "fade1_psu1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from fade1_psu1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 18)
# 	Splitting "fade1_psu1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from fade1_psu2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 19)
# 	Splitting "fade1_psu2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from fade1_psu2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 20)
# 	Splitting "fade1_psu2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from fade1_psu2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 21)
# 	Splitting "fade1_psu2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 22)
# 	Splitting "psd1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 23)
# 	Splitting "psd1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 24)
# 	Splitting "psd1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd1_fade1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 25)
# 	Splitting "psd1_fade1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd1_fade1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 26)
# 	Splitting "psd1_fade1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd1_fade1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 27)
# 	Splitting "psd1_fade1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd1_psd1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 28)
# 	Splitting "psd1_psd1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd1_psd1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 29)
# 	Splitting "psd1_psd1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd1_psd1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 30)
# 	Splitting "psd1_psd1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd1_psd2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 31)
# 	Splitting "psd1_psd2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd1_psd2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 32)
# 	Splitting "psd1_psd2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd1_psd2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 33)
# 	Splitting "psd1_psd2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd1_psu1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 34)
# 	Splitting "psd1_psu1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd1_psu1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 35)
# 	Splitting "psd1_psu1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd1_psu1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 36)
# 	Splitting "psd1_psu1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd1_psu2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 37)
# 	Splitting "psd1_psu2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd1_psu2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 38)
# 	Splitting "psd1_psu2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd1_psu2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 39)
# 	Splitting "psd1_psu2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 40)
# 	Splitting "psd2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 41)
# 	Splitting "psd2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 42)
# 	Splitting "psd2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd2_fade1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 43)
# 	Splitting "psd2_fade1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd2_fade1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 44)
# 	Splitting "psd2_fade1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd2_fade1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 45)
# 	Splitting "psd2_fade1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd2_psd1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 46)
# 	Splitting "psd2_psd1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd2_psd1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 47)
# 	Splitting "psd2_psd1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd2_psd1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 48)
# 	Splitting "psd2_psd1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd2_psd2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 49)
# 	Splitting "psd2_psd2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd2_psd2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 50)
# 	Splitting "psd2_psd2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd2_psd2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 51)
# 	Splitting "psd2_psd2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd2_psu1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 52)
# 	Splitting "psd2_psu1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd2_psu1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 53)
# 	Splitting "psd2_psu1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd2_psu1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 54)
# 	Splitting "psd2_psu1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd2_psu2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 55)
# 	Splitting "psd2_psu2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd2_psu2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 56)
# 	Splitting "psd2_psu2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psd2_psu2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 57)
# 	Splitting "psd2_psu2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 58)
# 	Splitting "psu1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 59)
# 	Splitting "psu1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 60)
# 	Splitting "psu1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu1_fade1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 61)
# 	Splitting "psu1_fade1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu1_fade1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 62)
# 	Splitting "psu1_fade1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu1_fade1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 63)
# 	Splitting "psu1_fade1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu1_psd1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 64)
# 	Splitting "psu1_psd1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu1_psd1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 65)
# 	Splitting "psu1_psd1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu1_psd1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 66)
# 	Splitting "psu1_psd1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu1_psd2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 67)
# 	Splitting "psu1_psd2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu1_psd2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 68)
# 	Splitting "psu1_psd2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu1_psd2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 69)
# 	Splitting "psu1_psd2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu1_psu1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 70)
# 	Splitting "psu1_psu1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu1_psu1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 71)
# 	Splitting "psu1_psu1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu1_psu1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 72)
# 	Splitting "psu1_psu1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu1_psu2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 73)
# 	Splitting "psu1_psu2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu1_psu2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 74)
# 	Splitting "psu1_psu2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu1_psu2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 75)
# 	Splitting "psu1_psu2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 76)
# 	Splitting "psu2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 77)
# 	Splitting "psu2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 78)
# 	Splitting "psu2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu2_fade1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 79)
# 	Splitting "psu2_fade1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu2_fade1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 80)
# 	Splitting "psu2_fade1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu2_fade1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 81)
# 	Splitting "psu2_fade1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu2_psd1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 82)
# 	Splitting "psu2_psd1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu2_psd1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 83)
# 	Splitting "psu2_psd1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu2_psd1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 84)
# 	Splitting "psu2_psd1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu2_psd2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 85)
# 	Splitting "psu2_psd2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu2_psd2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 86)
# 	Splitting "psu2_psd2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu2_psd2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 87)
# 	Splitting "psu2_psd2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu2_psu1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 88)
# 	Splitting "psu2_psu1_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu2_psu1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 89)
# 	Splitting "psu2_psu1_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu2_psu1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 90)
# 	Splitting "psu2_psu1_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu2_psu2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav (# 91)
# 	Splitting "psu2_psu2_audiocheck.net_sweep_100Hz_1000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu2_psu2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav (# 92)
# 	Splitting "psu2_psu2_audiocheck.net_sweep_10Hz_10000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# Currently extracting features in "sweep" from psu2_psu2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav (# 93)
# 	Splitting "psu2_psu2_audiocheck.net_sweep_500Hz_2000Hz_-3dBFS_10s.wav" into 10 1-second part(s)
# ----- done. -----
# Total file count: 345
# Files ignored: 0
# Extracted 3410 windows from 345 Files
# Shape of dataframe: (3410, 40, 28)
# Shape of labels: (3410,)
# Shape of LEQs: (3410,)

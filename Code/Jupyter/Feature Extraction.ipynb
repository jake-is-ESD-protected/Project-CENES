# %% [markdown]
# # Feature Extraction
#
# Since the filters have been explored, the data displayed in spectrograms can now be written to `csv`-files for later training of the NN. The amount of data per soundfile is calculated with the following formula:
#
# ```
# size_in_b = n_frames * n_bands * sizeof(float32)
# ```
#
# This is one of the major strenghts of this method: instead of storing `512` bins `1024` times per second, the octave bank only creates `31` bins `24` times a second.

# %%
import os
from octafilt3r import filter as o3f
from octafilt3r import weightings as o3w
import librosa as lr
import numpy as np
import pipeline.config as conf

# %%
param_dict = conf.open_params()

# %%
files_ignored = 0
tot_cnt = 0

df = []
labels = []
leq = []
for class_ in os.listdir(param_dict["source_dir"]):
    cnt = 1
    for filename in os.listdir(f'{param_dict["source_dir"]}{class_}'):

        print(f'Currently extracting features in "{class_}" from {filename} (# {cnt})')

        wav = f'{param_dict["source_dir"]}{class_}/{filename}'
        y, sr = lr.load(wav, sr=param_dict["fs"], mono=True, duration=param_dict["max_dur"])

        y = o3w.A_weight(y, sr)

        wins = int(len(y)/param_dict["window_size"])
        if wins == 0:
            files_ignored += 1
            print('*ignored, file under 1 second long*')
            continue    # skip files which are shorter than 1s

        # obtain features of whole file
        feats, fcs, lq = o3f.rolling_oct_bank(y, 
                                        param_dict["fs"], 
                                        ratio=param_dict["oct_bw_ratio"], 
                                        fmax=param_dict["fmax"], 
                                        fmin=param_dict["fmin"], 
                                        frame_size=param_dict["frame_size"], 
                                        n_decimations=param_dict["dec_stages"])

        # flip array to match embedded system arrays
        feats = feats[:, ::-1]

        print(f'\tSplitting "{filename}" into {wins} 1-second part(s)')
        for win in range(wins):    # ignore parts of file which is not in a full window
            cur_feats = feats[param_dict["fps"] * win:param_dict["fps"] * (win + 1)]
            df.append(cur_feats)
            labels.append(class_)
            leq.append(lq[win])
        cnt += 1

    tot_cnt += cnt


df = np.dstack(df)
df = np.transpose(df, (2, 0, 1))

df_2d = df.reshape(df.shape[0], -1)
np.savetxt(param_dict["extr_txt_fp"], df_2d)
with open(param_dict["label_txt_fp"], "w") as f:
    for i in labels:
        f.writelines(i + '\n')
with open(param_dict["leq_txt_fp"], "w") as f:
    for i in leq:
        f.writelines(str(i) + '\n')        


print(f'----- done. -----\nTotal file count: {tot_cnt}\nFiles ignored: {files_ignored}\nExtracted {len(df)} windows from {tot_cnt-files_ignored} Files')
print(f'Shape of dataframe: {df.shape}')
print(f'Shape of labels: {np.shape(labels)}')
print(f'Shape of LEQs: {np.shape(leq)}')
# Out:
# Currently extracting features in "airplane" from 1-11687-A-47.wav (# 1)
# 	Splitting "1-11687-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 1-24796-A-47.wav (# 2)
# 	Splitting "1-24796-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 1-36929-A-47.wav (# 3)
# 	Splitting "1-36929-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 1-43807-A-47.wav (# 4)
# 	Splitting "1-43807-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 1-43807-B-47.wav (# 5)
# 	Splitting "1-43807-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 1-43807-C-47.wav (# 6)
# 	Splitting "1-43807-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 1-43807-D-47.wav (# 7)
# 	Splitting "1-43807-D-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 1-53467-A-47.wav (# 8)
# 	Splitting "1-53467-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 2-105270-A-47.wav (# 9)
# 	Splitting "2-105270-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 2-106849-A-47.wav (# 10)
# 	Splitting "2-106849-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 2-160888-A-47.wav (# 11)
# 	Splitting "2-160888-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 2-74361-A-47.wav (# 12)
# 	Splitting "2-74361-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 2-78781-A-47.wav (# 13)
# 	Splitting "2-78781-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 2-78799-A-47.wav (# 14)
# 	Splitting "2-78799-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 2-96654-A-47.wav (# 15)
# 	Splitting "2-96654-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 2-98866-A-47.wav (# 16)
# 	Splitting "2-98866-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 3-115387-A-47.wav (# 17)
# 	Splitting "3-115387-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 3-115387-B-47.wav (# 18)
# 	Splitting "3-115387-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 3-115387-C-47.wav (# 19)
# 	Splitting "3-115387-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 3-128512-A-47.wav (# 20)
# 	Splitting "3-128512-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 3-128512-B-47.wav (# 21)
# 	Splitting "3-128512-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 3-143560-A-47.wav (# 22)
# 	Splitting "3-143560-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 3-143562-A-47.wav (# 23)
# 	Splitting "3-143562-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 3-193767-A-47.wav (# 24)
# 	Splitting "3-193767-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 4-161099-A-47.wav (# 25)
# 	Splitting "4-161099-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 4-161099-B-47.wav (# 26)
# 	Splitting "4-161099-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 4-161100-A-47.wav (# 27)
# 	Splitting "4-161100-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 4-161103-A-47.wav (# 28)
# 	Splitting "4-161103-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 4-161105-A-47.wav (# 29)
# 	Splitting "4-161105-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 4-161105-B-47.wav (# 30)
# 	Splitting "4-161105-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 4-251959-A-47.wav (# 31)
# 	Splitting "4-251959-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 4-255371-A-47.wav (# 32)
# 	Splitting "4-255371-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 5-215445-A-47.wav (# 33)
# 	Splitting "5-215445-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 5-215447-A-47.wav (# 34)
# 	Splitting "5-215447-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 5-215449-A-47.wav (# 35)
# 	Splitting "5-215449-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 5-235956-A-47.wav (# 36)
# 	Splitting "5-235956-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 5-251957-A-47.wav (# 37)
# 	Splitting "5-251957-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 5-251962-A-47.wav (# 38)
# 	Splitting "5-251962-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 5-251963-A-47.wav (# 39)
# 	Splitting "5-251963-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 5-251971-A-47.wav (# 40)
# 	Splitting "5-251971-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_1-11687-A-47.wav (# 41)
# 	Splitting "fade1_1-11687-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_1-24796-A-47.wav (# 42)
# 	Splitting "fade1_1-24796-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_1-36929-A-47.wav (# 43)
# 	Splitting "fade1_1-36929-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_1-43807-A-47.wav (# 44)
# 	Splitting "fade1_1-43807-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_1-43807-B-47.wav (# 45)
# 	Splitting "fade1_1-43807-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_1-43807-C-47.wav (# 46)
# 	Splitting "fade1_1-43807-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_1-43807-D-47.wav (# 47)
# 	Splitting "fade1_1-43807-D-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_1-53467-A-47.wav (# 48)
# 	Splitting "fade1_1-53467-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_2-105270-A-47.wav (# 49)
# 	Splitting "fade1_2-105270-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_2-106849-A-47.wav (# 50)
# 	Splitting "fade1_2-106849-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_2-160888-A-47.wav (# 51)
# 	Splitting "fade1_2-160888-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_2-74361-A-47.wav (# 52)
# 	Splitting "fade1_2-74361-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_2-78781-A-47.wav (# 53)
# 	Splitting "fade1_2-78781-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_2-78799-A-47.wav (# 54)
# 	Splitting "fade1_2-78799-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_2-96654-A-47.wav (# 55)
# 	Splitting "fade1_2-96654-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_2-98866-A-47.wav (# 56)
# 	Splitting "fade1_2-98866-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_3-115387-A-47.wav (# 57)
# 	Splitting "fade1_3-115387-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_3-115387-B-47.wav (# 58)
# 	Splitting "fade1_3-115387-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_3-115387-C-47.wav (# 59)
# 	Splitting "fade1_3-115387-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_3-128512-A-47.wav (# 60)
# 	Splitting "fade1_3-128512-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_3-128512-B-47.wav (# 61)
# 	Splitting "fade1_3-128512-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_3-143560-A-47.wav (# 62)
# 	Splitting "fade1_3-143560-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_3-143562-A-47.wav (# 63)
# 	Splitting "fade1_3-143562-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_3-193767-A-47.wav (# 64)
# 	Splitting "fade1_3-193767-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_4-161099-A-47.wav (# 65)
# 	Splitting "fade1_4-161099-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_4-161099-B-47.wav (# 66)
# 	Splitting "fade1_4-161099-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_4-161100-A-47.wav (# 67)
# 	Splitting "fade1_4-161100-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_4-161103-A-47.wav (# 68)
# 	Splitting "fade1_4-161103-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_4-161105-A-47.wav (# 69)
# 	Splitting "fade1_4-161105-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_4-161105-B-47.wav (# 70)
# 	Splitting "fade1_4-161105-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_4-251959-A-47.wav (# 71)
# 	Splitting "fade1_4-251959-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_4-255371-A-47.wav (# 72)
# 	Splitting "fade1_4-255371-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_5-215445-A-47.wav (# 73)
# 	Splitting "fade1_5-215445-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_5-215447-A-47.wav (# 74)
# 	Splitting "fade1_5-215447-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_5-215449-A-47.wav (# 75)
# 	Splitting "fade1_5-215449-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_5-235956-A-47.wav (# 76)
# 	Splitting "fade1_5-235956-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_5-251957-A-47.wav (# 77)
# 	Splitting "fade1_5-251957-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_5-251962-A-47.wav (# 78)
# 	Splitting "fade1_5-251962-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_5-251963-A-47.wav (# 79)
# 	Splitting "fade1_5-251963-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade1_5-251971-A-47.wav (# 80)
# 	Splitting "fade1_5-251971-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_1-11687-A-47.wav (# 81)
# 	Splitting "fade2_1-11687-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_1-24796-A-47.wav (# 82)
# 	Splitting "fade2_1-24796-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_1-36929-A-47.wav (# 83)
# 	Splitting "fade2_1-36929-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_1-43807-A-47.wav (# 84)
# 	Splitting "fade2_1-43807-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_1-43807-B-47.wav (# 85)
# 	Splitting "fade2_1-43807-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_1-43807-C-47.wav (# 86)
# 	Splitting "fade2_1-43807-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_1-43807-D-47.wav (# 87)
# 	Splitting "fade2_1-43807-D-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_1-53467-A-47.wav (# 88)
# 	Splitting "fade2_1-53467-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_2-105270-A-47.wav (# 89)
# 	Splitting "fade2_2-105270-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_2-106849-A-47.wav (# 90)
# 	Splitting "fade2_2-106849-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_2-160888-A-47.wav (# 91)
# 	Splitting "fade2_2-160888-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_2-74361-A-47.wav (# 92)
# 	Splitting "fade2_2-74361-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_2-78781-A-47.wav (# 93)
# 	Splitting "fade2_2-78781-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_2-78799-A-47.wav (# 94)
# 	Splitting "fade2_2-78799-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_2-96654-A-47.wav (# 95)
# 	Splitting "fade2_2-96654-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_2-98866-A-47.wav (# 96)
# 	Splitting "fade2_2-98866-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_3-115387-A-47.wav (# 97)
# 	Splitting "fade2_3-115387-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_3-115387-B-47.wav (# 98)
# 	Splitting "fade2_3-115387-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_3-115387-C-47.wav (# 99)
# 	Splitting "fade2_3-115387-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_3-128512-A-47.wav (# 100)
# 	Splitting "fade2_3-128512-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_3-128512-B-47.wav (# 101)
# 	Splitting "fade2_3-128512-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_3-143560-A-47.wav (# 102)
# 	Splitting "fade2_3-143560-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_3-143562-A-47.wav (# 103)
# 	Splitting "fade2_3-143562-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_3-193767-A-47.wav (# 104)
# 	Splitting "fade2_3-193767-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_4-161099-A-47.wav (# 105)
# 	Splitting "fade2_4-161099-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_4-161099-B-47.wav (# 106)
# 	Splitting "fade2_4-161099-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_4-161100-A-47.wav (# 107)
# 	Splitting "fade2_4-161100-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_4-161103-A-47.wav (# 108)
# 	Splitting "fade2_4-161103-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_4-161105-A-47.wav (# 109)
# 	Splitting "fade2_4-161105-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_4-161105-B-47.wav (# 110)
# 	Splitting "fade2_4-161105-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_4-251959-A-47.wav (# 111)
# 	Splitting "fade2_4-251959-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_4-255371-A-47.wav (# 112)
# 	Splitting "fade2_4-255371-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_5-215445-A-47.wav (# 113)
# 	Splitting "fade2_5-215445-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_5-215447-A-47.wav (# 114)
# 	Splitting "fade2_5-215447-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_5-215449-A-47.wav (# 115)
# 	Splitting "fade2_5-215449-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_5-235956-A-47.wav (# 116)
# 	Splitting "fade2_5-235956-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_5-251957-A-47.wav (# 117)
# 	Splitting "fade2_5-251957-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_5-251962-A-47.wav (# 118)
# 	Splitting "fade2_5-251962-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_5-251963-A-47.wav (# 119)
# 	Splitting "fade2_5-251963-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from fade2_5-251971-A-47.wav (# 120)
# 	Splitting "fade2_5-251971-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_1-11687-A-47.wav (# 121)
# 	Splitting "n_1-11687-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_1-24796-A-47.wav (# 122)
# 	Splitting "n_1-24796-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_1-36929-A-47.wav (# 123)
# 	Splitting "n_1-36929-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_1-43807-A-47.wav (# 124)
# 	Splitting "n_1-43807-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_1-43807-B-47.wav (# 125)
# 	Splitting "n_1-43807-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_1-43807-C-47.wav (# 126)
# 	Splitting "n_1-43807-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_1-43807-D-47.wav (# 127)
# 	Splitting "n_1-43807-D-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_1-53467-A-47.wav (# 128)
# 	Splitting "n_1-53467-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_2-105270-A-47.wav (# 129)
# 	Splitting "n_2-105270-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_2-106849-A-47.wav (# 130)
# 	Splitting "n_2-106849-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_2-160888-A-47.wav (# 131)
# 	Splitting "n_2-160888-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_2-74361-A-47.wav (# 132)
# 	Splitting "n_2-74361-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_2-78781-A-47.wav (# 133)
# 	Splitting "n_2-78781-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_2-78799-A-47.wav (# 134)
# 	Splitting "n_2-78799-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_2-96654-A-47.wav (# 135)
# 	Splitting "n_2-96654-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_2-98866-A-47.wav (# 136)
# 	Splitting "n_2-98866-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_3-115387-A-47.wav (# 137)
# 	Splitting "n_3-115387-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_3-115387-B-47.wav (# 138)
# 	Splitting "n_3-115387-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_3-115387-C-47.wav (# 139)
# 	Splitting "n_3-115387-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_3-128512-A-47.wav (# 140)
# 	Splitting "n_3-128512-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_3-128512-B-47.wav (# 141)
# 	Splitting "n_3-128512-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_3-143560-A-47.wav (# 142)
# 	Splitting "n_3-143560-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_3-143562-A-47.wav (# 143)
# 	Splitting "n_3-143562-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_3-193767-A-47.wav (# 144)
# 	Splitting "n_3-193767-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_4-161099-A-47.wav (# 145)
# 	Splitting "n_4-161099-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_4-161099-B-47.wav (# 146)
# 	Splitting "n_4-161099-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_4-161100-A-47.wav (# 147)
# 	Splitting "n_4-161100-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_4-161103-A-47.wav (# 148)
# 	Splitting "n_4-161103-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_4-161105-A-47.wav (# 149)
# 	Splitting "n_4-161105-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_4-161105-B-47.wav (# 150)
# 	Splitting "n_4-161105-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_4-251959-A-47.wav (# 151)
# 	Splitting "n_4-251959-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_4-255371-A-47.wav (# 152)
# 	Splitting "n_4-255371-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_5-215445-A-47.wav (# 153)
# 	Splitting "n_5-215445-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_5-215447-A-47.wav (# 154)
# 	Splitting "n_5-215447-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_5-215449-A-47.wav (# 155)
# 	Splitting "n_5-215449-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_5-235956-A-47.wav (# 156)
# 	Splitting "n_5-235956-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_5-251957-A-47.wav (# 157)
# 	Splitting "n_5-251957-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_5-251962-A-47.wav (# 158)
# 	Splitting "n_5-251962-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_5-251963-A-47.wav (# 159)
# 	Splitting "n_5-251963-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_5-251971-A-47.wav (# 160)
# 	Splitting "n_5-251971-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from offs025_1-11687-A-47.wav (# 161)
# 	Splitting "offs025_1-11687-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_1-24796-A-47.wav (# 162)
# 	Splitting "offs025_1-24796-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_1-36929-A-47.wav (# 163)
# 	Splitting "offs025_1-36929-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_1-43807-A-47.wav (# 164)
# 	Splitting "offs025_1-43807-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_1-43807-B-47.wav (# 165)
# 	Splitting "offs025_1-43807-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_1-43807-C-47.wav (# 166)
# 	Splitting "offs025_1-43807-C-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_1-43807-D-47.wav (# 167)
# 	Splitting "offs025_1-43807-D-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_1-53467-A-47.wav (# 168)
# 	Splitting "offs025_1-53467-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_2-105270-A-47.wav (# 169)
# 	Splitting "offs025_2-105270-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_2-106849-A-47.wav (# 170)
# 	Splitting "offs025_2-106849-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_2-160888-A-47.wav (# 171)
# 	Splitting "offs025_2-160888-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_2-74361-A-47.wav (# 172)
# 	Splitting "offs025_2-74361-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_2-78781-A-47.wav (# 173)
# 	Splitting "offs025_2-78781-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_2-78799-A-47.wav (# 174)
# 	Splitting "offs025_2-78799-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_2-96654-A-47.wav (# 175)
# 	Splitting "offs025_2-96654-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_2-98866-A-47.wav (# 176)
# 	Splitting "offs025_2-98866-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_3-115387-A-47.wav (# 177)
# 	Splitting "offs025_3-115387-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_3-115387-B-47.wav (# 178)
# 	Splitting "offs025_3-115387-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_3-115387-C-47.wav (# 179)
# 	Splitting "offs025_3-115387-C-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_3-128512-A-47.wav (# 180)
# 	Splitting "offs025_3-128512-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_3-128512-B-47.wav (# 181)
# 	Splitting "offs025_3-128512-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_3-143560-A-47.wav (# 182)
# 	Splitting "offs025_3-143560-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_3-143562-A-47.wav (# 183)
# 	Splitting "offs025_3-143562-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_3-193767-A-47.wav (# 184)
# 	Splitting "offs025_3-193767-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_4-161099-A-47.wav (# 185)
# 	Splitting "offs025_4-161099-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_4-161099-B-47.wav (# 186)
# 	Splitting "offs025_4-161099-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_4-161100-A-47.wav (# 187)
# 	Splitting "offs025_4-161100-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_4-161103-A-47.wav (# 188)
# 	Splitting "offs025_4-161103-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_4-161105-A-47.wav (# 189)
# 	Splitting "offs025_4-161105-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_4-161105-B-47.wav (# 190)
# 	Splitting "offs025_4-161105-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_4-251959-A-47.wav (# 191)
# 	Splitting "offs025_4-251959-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_4-255371-A-47.wav (# 192)
# 	Splitting "offs025_4-255371-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_5-215445-A-47.wav (# 193)
# 	Splitting "offs025_5-215445-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_5-215447-A-47.wav (# 194)
# 	Splitting "offs025_5-215447-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_5-215449-A-47.wav (# 195)
# 	Splitting "offs025_5-215449-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_5-235956-A-47.wav (# 196)
# 	Splitting "offs025_5-235956-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_5-251957-A-47.wav (# 197)
# 	Splitting "offs025_5-251957-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_5-251962-A-47.wav (# 198)
# 	Splitting "offs025_5-251962-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_5-251963-A-47.wav (# 199)
# 	Splitting "offs025_5-251963-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_5-251971-A-47.wav (# 200)
# 	Splitting "offs025_5-251971-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_1-11687-A-47.wav (# 201)
# 	Splitting "offs05_1-11687-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_1-24796-A-47.wav (# 202)
# 	Splitting "offs05_1-24796-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_1-36929-A-47.wav (# 203)
# 	Splitting "offs05_1-36929-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_1-43807-A-47.wav (# 204)
# 	Splitting "offs05_1-43807-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_1-43807-B-47.wav (# 205)
# 	Splitting "offs05_1-43807-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_1-43807-C-47.wav (# 206)
# 	Splitting "offs05_1-43807-C-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_1-43807-D-47.wav (# 207)
# 	Splitting "offs05_1-43807-D-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_1-53467-A-47.wav (# 208)
# 	Splitting "offs05_1-53467-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_2-105270-A-47.wav (# 209)
# 	Splitting "offs05_2-105270-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_2-106849-A-47.wav (# 210)
# 	Splitting "offs05_2-106849-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_2-160888-A-47.wav (# 211)
# 	Splitting "offs05_2-160888-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_2-74361-A-47.wav (# 212)
# 	Splitting "offs05_2-74361-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_2-78781-A-47.wav (# 213)
# 	Splitting "offs05_2-78781-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_2-78799-A-47.wav (# 214)
# 	Splitting "offs05_2-78799-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_2-96654-A-47.wav (# 215)
# 	Splitting "offs05_2-96654-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_2-98866-A-47.wav (# 216)
# 	Splitting "offs05_2-98866-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_3-115387-A-47.wav (# 217)
# 	Splitting "offs05_3-115387-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_3-115387-B-47.wav (# 218)
# 	Splitting "offs05_3-115387-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_3-115387-C-47.wav (# 219)
# 	Splitting "offs05_3-115387-C-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_3-128512-A-47.wav (# 220)
# 	Splitting "offs05_3-128512-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_3-128512-B-47.wav (# 221)
# 	Splitting "offs05_3-128512-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_3-143560-A-47.wav (# 222)
# 	Splitting "offs05_3-143560-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_3-143562-A-47.wav (# 223)
# 	Splitting "offs05_3-143562-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_3-193767-A-47.wav (# 224)
# 	Splitting "offs05_3-193767-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_4-161099-A-47.wav (# 225)
# 	Splitting "offs05_4-161099-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_4-161099-B-47.wav (# 226)
# 	Splitting "offs05_4-161099-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_4-161100-A-47.wav (# 227)
# 	Splitting "offs05_4-161100-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_4-161103-A-47.wav (# 228)
# 	Splitting "offs05_4-161103-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_4-161105-A-47.wav (# 229)
# 	Splitting "offs05_4-161105-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_4-161105-B-47.wav (# 230)
# 	Splitting "offs05_4-161105-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_4-251959-A-47.wav (# 231)
# 	Splitting "offs05_4-251959-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_4-255371-A-47.wav (# 232)
# 	Splitting "offs05_4-255371-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_5-215445-A-47.wav (# 233)
# 	Splitting "offs05_5-215445-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_5-215447-A-47.wav (# 234)
# 	Splitting "offs05_5-215447-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_5-215449-A-47.wav (# 235)
# 	Splitting "offs05_5-215449-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_5-235956-A-47.wav (# 236)
# 	Splitting "offs05_5-235956-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_5-251957-A-47.wav (# 237)
# 	Splitting "offs05_5-251957-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_5-251962-A-47.wav (# 238)
# 	Splitting "offs05_5-251962-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_5-251963-A-47.wav (# 239)
# 	Splitting "offs05_5-251963-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_5-251971-A-47.wav (# 240)
# 	Splitting "offs05_5-251971-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_1-11687-A-47.wav (# 241)
# 	Splitting "offs075_1-11687-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_1-24796-A-47.wav (# 242)
# 	Splitting "offs075_1-24796-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_1-36929-A-47.wav (# 243)
# 	Splitting "offs075_1-36929-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_1-43807-A-47.wav (# 244)
# 	Splitting "offs075_1-43807-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_1-43807-B-47.wav (# 245)
# 	Splitting "offs075_1-43807-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_1-43807-C-47.wav (# 246)
# 	Splitting "offs075_1-43807-C-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_1-43807-D-47.wav (# 247)
# 	Splitting "offs075_1-43807-D-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_1-53467-A-47.wav (# 248)
# 	Splitting "offs075_1-53467-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_2-105270-A-47.wav (# 249)
# 	Splitting "offs075_2-105270-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_2-106849-A-47.wav (# 250)
# 	Splitting "offs075_2-106849-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_2-160888-A-47.wav (# 251)
# 	Splitting "offs075_2-160888-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_2-74361-A-47.wav (# 252)
# 	Splitting "offs075_2-74361-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_2-78781-A-47.wav (# 253)
# 	Splitting "offs075_2-78781-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_2-78799-A-47.wav (# 254)
# 	Splitting "offs075_2-78799-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_2-96654-A-47.wav (# 255)
# 	Splitting "offs075_2-96654-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_2-98866-A-47.wav (# 256)
# 	Splitting "offs075_2-98866-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_3-115387-A-47.wav (# 257)
# 	Splitting "offs075_3-115387-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_3-115387-B-47.wav (# 258)
# 	Splitting "offs075_3-115387-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_3-115387-C-47.wav (# 259)
# 	Splitting "offs075_3-115387-C-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_3-128512-A-47.wav (# 260)
# 	Splitting "offs075_3-128512-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_3-128512-B-47.wav (# 261)
# 	Splitting "offs075_3-128512-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_3-143560-A-47.wav (# 262)
# 	Splitting "offs075_3-143560-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_3-143562-A-47.wav (# 263)
# 	Splitting "offs075_3-143562-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_3-193767-A-47.wav (# 264)
# 	Splitting "offs075_3-193767-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_4-161099-A-47.wav (# 265)
# 	Splitting "offs075_4-161099-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_4-161099-B-47.wav (# 266)
# 	Splitting "offs075_4-161099-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_4-161100-A-47.wav (# 267)
# 	Splitting "offs075_4-161100-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_4-161103-A-47.wav (# 268)
# 	Splitting "offs075_4-161103-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_4-161105-A-47.wav (# 269)
# 	Splitting "offs075_4-161105-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_4-161105-B-47.wav (# 270)
# 	Splitting "offs075_4-161105-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_4-251959-A-47.wav (# 271)
# 	Splitting "offs075_4-251959-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_4-255371-A-47.wav (# 272)
# 	Splitting "offs075_4-255371-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_5-215445-A-47.wav (# 273)
# 	Splitting "offs075_5-215445-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_5-215447-A-47.wav (# 274)
# 	Splitting "offs075_5-215447-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_5-215449-A-47.wav (# 275)
# 	Splitting "offs075_5-215449-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_5-235956-A-47.wav (# 276)
# 	Splitting "offs075_5-235956-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_5-251957-A-47.wav (# 277)
# 	Splitting "offs075_5-251957-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_5-251962-A-47.wav (# 278)
# 	Splitting "offs075_5-251962-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_5-251963-A-47.wav (# 279)
# 	Splitting "offs075_5-251963-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_5-251971-A-47.wav (# 280)
# 	Splitting "offs075_5-251971-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from psd1_1-11687-A-47.wav (# 281)
# 	Splitting "psd1_1-11687-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_1-24796-A-47.wav (# 282)
# 	Splitting "psd1_1-24796-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_1-36929-A-47.wav (# 283)
# 	Splitting "psd1_1-36929-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_1-43807-A-47.wav (# 284)
# 	Splitting "psd1_1-43807-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_1-43807-B-47.wav (# 285)
# 	Splitting "psd1_1-43807-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_1-43807-C-47.wav (# 286)
# 	Splitting "psd1_1-43807-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_1-43807-D-47.wav (# 287)
# 	Splitting "psd1_1-43807-D-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_1-53467-A-47.wav (# 288)
# 	Splitting "psd1_1-53467-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_2-105270-A-47.wav (# 289)
# 	Splitting "psd1_2-105270-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_2-106849-A-47.wav (# 290)
# 	Splitting "psd1_2-106849-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_2-160888-A-47.wav (# 291)
# 	Splitting "psd1_2-160888-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_2-74361-A-47.wav (# 292)
# 	Splitting "psd1_2-74361-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_2-78781-A-47.wav (# 293)
# 	Splitting "psd1_2-78781-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_2-78799-A-47.wav (# 294)
# 	Splitting "psd1_2-78799-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_2-96654-A-47.wav (# 295)
# 	Splitting "psd1_2-96654-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_2-98866-A-47.wav (# 296)
# 	Splitting "psd1_2-98866-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_3-115387-A-47.wav (# 297)
# 	Splitting "psd1_3-115387-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_3-115387-B-47.wav (# 298)
# 	Splitting "psd1_3-115387-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_3-115387-C-47.wav (# 299)
# 	Splitting "psd1_3-115387-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_3-128512-A-47.wav (# 300)
# 	Splitting "psd1_3-128512-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_3-128512-B-47.wav (# 301)
# 	Splitting "psd1_3-128512-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_3-143560-A-47.wav (# 302)
# 	Splitting "psd1_3-143560-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_3-143562-A-47.wav (# 303)
# 	Splitting "psd1_3-143562-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_3-193767-A-47.wav (# 304)
# 	Splitting "psd1_3-193767-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_4-161099-A-47.wav (# 305)
# 	Splitting "psd1_4-161099-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_4-161099-B-47.wav (# 306)
# 	Splitting "psd1_4-161099-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_4-161100-A-47.wav (# 307)
# 	Splitting "psd1_4-161100-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_4-161103-A-47.wav (# 308)
# 	Splitting "psd1_4-161103-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_4-161105-A-47.wav (# 309)
# 	Splitting "psd1_4-161105-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_4-161105-B-47.wav (# 310)
# 	Splitting "psd1_4-161105-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_4-251959-A-47.wav (# 311)
# 	Splitting "psd1_4-251959-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_4-255371-A-47.wav (# 312)
# 	Splitting "psd1_4-255371-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_5-215445-A-47.wav (# 313)
# 	Splitting "psd1_5-215445-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_5-215447-A-47.wav (# 314)
# 	Splitting "psd1_5-215447-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_5-215449-A-47.wav (# 315)
# 	Splitting "psd1_5-215449-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_5-235956-A-47.wav (# 316)
# 	Splitting "psd1_5-235956-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_5-251957-A-47.wav (# 317)
# 	Splitting "psd1_5-251957-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_5-251962-A-47.wav (# 318)
# 	Splitting "psd1_5-251962-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_5-251963-A-47.wav (# 319)
# 	Splitting "psd1_5-251963-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_5-251971-A-47.wav (# 320)
# 	Splitting "psd1_5-251971-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_1-11687-A-47.wav (# 321)
# 	Splitting "psd2_1-11687-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_1-24796-A-47.wav (# 322)
# 	Splitting "psd2_1-24796-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_1-36929-A-47.wav (# 323)
# 	Splitting "psd2_1-36929-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_1-43807-A-47.wav (# 324)
# 	Splitting "psd2_1-43807-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_1-43807-B-47.wav (# 325)
# 	Splitting "psd2_1-43807-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_1-43807-C-47.wav (# 326)
# 	Splitting "psd2_1-43807-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_1-43807-D-47.wav (# 327)
# 	Splitting "psd2_1-43807-D-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_1-53467-A-47.wav (# 328)
# 	Splitting "psd2_1-53467-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_2-105270-A-47.wav (# 329)
# 	Splitting "psd2_2-105270-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_2-106849-A-47.wav (# 330)
# 	Splitting "psd2_2-106849-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_2-160888-A-47.wav (# 331)
# 	Splitting "psd2_2-160888-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_2-74361-A-47.wav (# 332)
# 	Splitting "psd2_2-74361-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_2-78781-A-47.wav (# 333)
# 	Splitting "psd2_2-78781-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_2-78799-A-47.wav (# 334)
# 	Splitting "psd2_2-78799-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_2-96654-A-47.wav (# 335)
# 	Splitting "psd2_2-96654-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_2-98866-A-47.wav (# 336)
# 	Splitting "psd2_2-98866-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_3-115387-A-47.wav (# 337)
# 	Splitting "psd2_3-115387-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_3-115387-B-47.wav (# 338)
# 	Splitting "psd2_3-115387-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_3-115387-C-47.wav (# 339)
# 	Splitting "psd2_3-115387-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_3-128512-A-47.wav (# 340)
# 	Splitting "psd2_3-128512-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_3-128512-B-47.wav (# 341)
# 	Splitting "psd2_3-128512-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_3-143560-A-47.wav (# 342)
# 	Splitting "psd2_3-143560-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_3-143562-A-47.wav (# 343)
# 	Splitting "psd2_3-143562-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_3-193767-A-47.wav (# 344)
# 	Splitting "psd2_3-193767-A-47.wav" into 5 1-second part(s)
# ...
# 	Splitting "psd2_1-64473-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_1-70300-A-45.wav (# 326)
# 	Splitting "psd2_1-70300-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_1-88409-A-45.wav (# 327)
# 	Splitting "psd2_1-88409-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_1-88409-B-45.wav (# 328)
# 	Splitting "psd2_1-88409-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_2-122066-A-45.wav (# 329)
# 	Splitting "psd2_2-122066-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_2-122066-B-45.wav (# 330)
# 	Splitting "psd2_2-122066-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_2-122067-A-45.wav (# 331)
# 	Splitting "psd2_2-122067-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_2-122067-B-45.wav (# 332)
# 	Splitting "psd2_2-122067-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_2-135649-A-45.wav (# 333)
# 	Splitting "psd2_2-135649-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_2-135649-B-45.wav (# 334)
# 	Splitting "psd2_2-135649-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_2-135649-C-45.wav (# 335)
# 	Splitting "psd2_2-135649-C-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_2-262579-A-45.wav (# 336)
# 	Splitting "psd2_2-262579-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_3-135650-A-45.wav (# 337)
# 	Splitting "psd2_3-135650-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_3-135650-B-45.wav (# 338)
# 	Splitting "psd2_3-135650-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_3-136451-A-45.wav (# 339)
# 	Splitting "psd2_3-136451-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_3-138212-A-45.wav (# 340)
# 	Splitting "psd2_3-138212-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_3-141559-A-45.wav (# 341)
# 	Splitting "psd2_3-141559-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_3-157492-A-45.wav (# 342)
# 	Splitting "psd2_3-157492-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_3-159445-A-45.wav (# 343)
# 	Splitting "psd2_3-159445-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_3-159445-B-45.wav (# 344)
# 	Splitting "psd2_3-159445-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_4-165606-A-45.wav (# 345)
# 	Splitting "psd2_4-165606-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_4-165791-A-45.wav (# 346)
# 	Splitting "psd2_4-165791-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_4-165791-B-45.wav (# 347)
# 	Splitting "psd2_4-165791-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_4-165845-A-45.wav (# 348)
# 	Splitting "psd2_4-165845-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_4-165845-B-45.wav (# 349)
# 	Splitting "psd2_4-165845-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_4-165933-A-45.wav (# 350)
# 	Splitting "psd2_4-165933-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_4-168446-A-45.wav (# 351)
# 	Splitting "psd2_4-168446-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_4-178881-A-45.wav (# 352)
# 	Splitting "psd2_4-178881-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_5-188796-A-45.wav (# 353)
# 	Splitting "psd2_5-188796-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_5-188945-A-45.wav (# 354)
# 	Splitting "psd2_5-188945-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_5-197118-A-45.wav (# 355)
# 	Splitting "psd2_5-197118-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_5-197121-A-45.wav (# 356)
# 	Splitting "psd2_5-197121-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_5-197121-B-45.wav (# 357)
# 	Splitting "psd2_5-197121-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_5-198600-A-45.wav (# 358)
# 	Splitting "psd2_5-198600-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_5-199284-A-45.wav (# 359)
# 	Splitting "psd2_5-199284-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psd2_5-199284-B-45.wav (# 360)
# 	Splitting "psd2_5-199284-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_1-119125-A-45.wav (# 361)
# 	Splitting "psu1_1-119125-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_1-54065-A-45.wav (# 362)
# 	Splitting "psu1_1-54065-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_1-54065-B-45.wav (# 363)
# 	Splitting "psu1_1-54065-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_1-62509-A-45.wav (# 364)
# 	Splitting "psu1_1-62509-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_1-64473-A-45.wav (# 365)
# 	Splitting "psu1_1-64473-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_1-70300-A-45.wav (# 366)
# 	Splitting "psu1_1-70300-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_1-88409-A-45.wav (# 367)
# 	Splitting "psu1_1-88409-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_1-88409-B-45.wav (# 368)
# 	Splitting "psu1_1-88409-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_2-122066-A-45.wav (# 369)
# 	Splitting "psu1_2-122066-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_2-122066-B-45.wav (# 370)
# 	Splitting "psu1_2-122066-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_2-122067-A-45.wav (# 371)
# 	Splitting "psu1_2-122067-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_2-122067-B-45.wav (# 372)
# 	Splitting "psu1_2-122067-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_2-135649-A-45.wav (# 373)
# 	Splitting "psu1_2-135649-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_2-135649-B-45.wav (# 374)
# 	Splitting "psu1_2-135649-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_2-135649-C-45.wav (# 375)
# 	Splitting "psu1_2-135649-C-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_2-262579-A-45.wav (# 376)
# 	Splitting "psu1_2-262579-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_3-135650-A-45.wav (# 377)
# 	Splitting "psu1_3-135650-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_3-135650-B-45.wav (# 378)
# 	Splitting "psu1_3-135650-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_3-136451-A-45.wav (# 379)
# 	Splitting "psu1_3-136451-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_3-138212-A-45.wav (# 380)
# 	Splitting "psu1_3-138212-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_3-141559-A-45.wav (# 381)
# 	Splitting "psu1_3-141559-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_3-157492-A-45.wav (# 382)
# 	Splitting "psu1_3-157492-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_3-159445-A-45.wav (# 383)
# 	Splitting "psu1_3-159445-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_3-159445-B-45.wav (# 384)
# 	Splitting "psu1_3-159445-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_4-165606-A-45.wav (# 385)
# 	Splitting "psu1_4-165606-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_4-165791-A-45.wav (# 386)
# 	Splitting "psu1_4-165791-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_4-165791-B-45.wav (# 387)
# 	Splitting "psu1_4-165791-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_4-165845-A-45.wav (# 388)
# 	Splitting "psu1_4-165845-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_4-165845-B-45.wav (# 389)
# 	Splitting "psu1_4-165845-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_4-165933-A-45.wav (# 390)
# 	Splitting "psu1_4-165933-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_4-168446-A-45.wav (# 391)
# 	Splitting "psu1_4-168446-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_4-178881-A-45.wav (# 392)
# 	Splitting "psu1_4-178881-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_5-188796-A-45.wav (# 393)
# 	Splitting "psu1_5-188796-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_5-188945-A-45.wav (# 394)
# 	Splitting "psu1_5-188945-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_5-197118-A-45.wav (# 395)
# 	Splitting "psu1_5-197118-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_5-197121-A-45.wav (# 396)
# 	Splitting "psu1_5-197121-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_5-197121-B-45.wav (# 397)
# 	Splitting "psu1_5-197121-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_5-198600-A-45.wav (# 398)
# 	Splitting "psu1_5-198600-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_5-199284-A-45.wav (# 399)
# 	Splitting "psu1_5-199284-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu1_5-199284-B-45.wav (# 400)
# 	Splitting "psu1_5-199284-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_1-119125-A-45.wav (# 401)
# 	Splitting "psu2_1-119125-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_1-54065-A-45.wav (# 402)
# 	Splitting "psu2_1-54065-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_1-54065-B-45.wav (# 403)
# 	Splitting "psu2_1-54065-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_1-62509-A-45.wav (# 404)
# 	Splitting "psu2_1-62509-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_1-64473-A-45.wav (# 405)
# 	Splitting "psu2_1-64473-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_1-70300-A-45.wav (# 406)
# 	Splitting "psu2_1-70300-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_1-88409-A-45.wav (# 407)
# 	Splitting "psu2_1-88409-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_1-88409-B-45.wav (# 408)
# 	Splitting "psu2_1-88409-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_2-122066-A-45.wav (# 409)
# 	Splitting "psu2_2-122066-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_2-122066-B-45.wav (# 410)
# 	Splitting "psu2_2-122066-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_2-122067-A-45.wav (# 411)
# 	Splitting "psu2_2-122067-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_2-122067-B-45.wav (# 412)
# 	Splitting "psu2_2-122067-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_2-135649-A-45.wav (# 413)
# 	Splitting "psu2_2-135649-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_2-135649-B-45.wav (# 414)
# 	Splitting "psu2_2-135649-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_2-135649-C-45.wav (# 415)
# 	Splitting "psu2_2-135649-C-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_2-262579-A-45.wav (# 416)
# 	Splitting "psu2_2-262579-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_3-135650-A-45.wav (# 417)
# 	Splitting "psu2_3-135650-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_3-135650-B-45.wav (# 418)
# 	Splitting "psu2_3-135650-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_3-136451-A-45.wav (# 419)
# 	Splitting "psu2_3-136451-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_3-138212-A-45.wav (# 420)
# 	Splitting "psu2_3-138212-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_3-141559-A-45.wav (# 421)
# 	Splitting "psu2_3-141559-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_3-157492-A-45.wav (# 422)
# 	Splitting "psu2_3-157492-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_3-159445-A-45.wav (# 423)
# 	Splitting "psu2_3-159445-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_3-159445-B-45.wav (# 424)
# 	Splitting "psu2_3-159445-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_4-165606-A-45.wav (# 425)
# 	Splitting "psu2_4-165606-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_4-165791-A-45.wav (# 426)
# 	Splitting "psu2_4-165791-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_4-165791-B-45.wav (# 427)
# 	Splitting "psu2_4-165791-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_4-165845-A-45.wav (# 428)
# 	Splitting "psu2_4-165845-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_4-165845-B-45.wav (# 429)
# 	Splitting "psu2_4-165845-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_4-165933-A-45.wav (# 430)
# 	Splitting "psu2_4-165933-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_4-168446-A-45.wav (# 431)
# 	Splitting "psu2_4-168446-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_4-178881-A-45.wav (# 432)
# 	Splitting "psu2_4-178881-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_5-188796-A-45.wav (# 433)
# 	Splitting "psu2_5-188796-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_5-188945-A-45.wav (# 434)
# 	Splitting "psu2_5-188945-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_5-197118-A-45.wav (# 435)
# 	Splitting "psu2_5-197118-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_5-197121-A-45.wav (# 436)
# 	Splitting "psu2_5-197121-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_5-197121-B-45.wav (# 437)
# 	Splitting "psu2_5-197121-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_5-198600-A-45.wav (# 438)
# 	Splitting "psu2_5-198600-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_5-199284-A-45.wav (# 439)
# 	Splitting "psu2_5-199284-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from psu2_5-199284-B-45.wav (# 440)
# 	Splitting "psu2_5-199284-B-45.wav" into 5 1-second part(s)
# ----- done. -----
# Total file count: 2646
# Files ignored: 0
# Extracted 12480 windows from 2646 Files
# Shape of dataframe: (12480, 40, 28)
# Shape of labels: (12480,)
# Shape of LEQs: (12480,)

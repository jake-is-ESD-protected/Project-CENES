# %% [markdown]
# # Feature Extraction
#
# Since the filters have been explored, the data displayed in spectrograms can now be written to `csv`-files for later training of the NN. The amount of data per soundfile is calculated with the following formula:
#
# ```
# size_in_b = n_frames * n_bands * sizeof(float32)
# ```
#
# This is one of the major strenghts of this method: instead of storing `512` bins `1024` times per second, the octave bank only creates `31` bins `24` times a second.

# %%
import os
from octafilt3r import filter as o3f
import librosa as lr
import numpy as np
import json


user_mode = False

# %%
if user_mode == 'y':
    txt_name = input("give your storage-file a name: ") + '.txt'
else:
    txt_name = "th_oct_feature.txt"

std_txt_fp = "Datasets/Feature_extraction/th_oct_coeffs.txt"
source_dir = 'Datasets/UrbanSoundMini/'

fs = 48000                              # sample rate
fmin = 100                              # lowest f of interest
fmax = 12800                            # highest f of interest
oct_bw_ratio = 1/3                      # octave / amount of subdivisions
order = 8                               # order of octave filters

n_coeffs_p_section = 6                  # constant, definition of sos-matrix
n_sections = int(order/2)               # number of biquads (order 2 filters)
dec_stages = 4                          # number of decimations across bank
dec_ord = 10                            # order of decimation AA-filters

frame_size = 1000                      # framing size
fps = int(fs / frame_size)
window_size = fs * 1
max_dur = 5                            # max duration of sound in s
_, _, _, n_bands = o3f._gen_fc_fl_fu(fmax, fmin, oct_bw_ratio)

param_dict_fp = 'param_dict.json'
param_dict = {  
    "txt name":txt_name,
    "std_txt_fp":std_txt_fp,
    "source_dir":source_dir,
    "fs":fs,
    "fmin":fmin,
    "fmax":fmax,
    "oct_bw_ratio":oct_bw_ratio,
    "order":order,
    "n_coeffs_p_section":n_coeffs_p_section,
    "n_sections":n_sections,
    "dec_stages":dec_stages,
    "dec_ord":dec_ord,
    "frame_size": frame_size,
    "fps":fps,
    "window_size": window_size,
    "max_dur":max_dur,
    "n_bands":n_bands
}

with open(param_dict_fp, 'w') as f:
    json.dump(param_dict, f)

# %%
files_ignored = 0
tot_cnt = 0

df = []
labels = []
for class_ in os.listdir(source_dir):
    cnt = 1
    for filename in os.listdir(f'{source_dir}{class_}'):

        print(f'Currently extracting features in "{class_}" from {filename} (# {cnt})')

        wav = f'{source_dir}{class_}/{filename}'
        y, sr = lr.load(wav, sr=fs, mono=True, duration=max_dur)

        wins = int(len(y)/window_size)
        if wins == 0:
            files_ignored += 1
            print('*ignored, file under 1 second long*')
            continue    # skip files which are shorter than 1s

        # obtain features of whole file
        feats, fcs = o3f.rolling_oct_bank(y, fs, ratio=oct_bw_ratio, fmax=fmax, fmin=fmin, frame_size=frame_size, n_decimations=dec_stages)

        print(f'\tSplitting "{filename}" into {wins} 1-second part(s)')
        for win in range(wins):    # ignore parts of file which is not in a full window
            cur_feats = feats[fps * win:fps * (win + 1)]
            df.append(cur_feats)
            labels.append(class_)
        cnt += 1

    tot_cnt += cnt

df = np.dstack(df)
df = np.transpose(df, (2, 0, 1))

df_2d = df.reshape(df.shape[0], -1)
np.savetxt("Datasets/Feature_extraction/th_oct_feature.txt", df_2d)
with open("Datasets/Feature_extraction/labels.txt", "w") as f:
    for i in labels:
        f.writelines(i + '\n')


print(f'----- done. -----\nTotal file count: {tot_cnt}\nFiles ignored: {files_ignored}\nExtracted {len(df)} windows from {tot_cnt-files_ignored} Files')
print(f'Shape of dataframe: {df.shape}')
# Out:
# Currently extracting features in "car_horn" from 199769-1-0-1.wav (# 1)
# 	Splitting "199769-1-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-10.wav (# 2)
# 	Splitting "199769-1-0-10.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-11.wav (# 3)
# 	Splitting "199769-1-0-11.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-12.wav (# 4)
# 	Splitting "199769-1-0-12.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-13.wav (# 5)
# 	Splitting "199769-1-0-13.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-14.wav (# 6)
# 	Splitting "199769-1-0-14.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-15.wav (# 7)
# 	Splitting "199769-1-0-15.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-16.wav (# 8)
# 	Splitting "199769-1-0-16.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-17.wav (# 9)
# 	Splitting "199769-1-0-17.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-18.wav (# 10)
# 	Splitting "199769-1-0-18.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-2.wav (# 11)
# 	Splitting "199769-1-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-3.wav (# 12)
# 	Splitting "199769-1-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-4.wav (# 13)
# 	Splitting "199769-1-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-5.wav (# 14)
# 	Splitting "199769-1-0-5.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-6.wav (# 15)
# 	Splitting "199769-1-0-6.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-7.wav (# 16)
# 	Splitting "199769-1-0-7.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-8.wav (# 17)
# 	Splitting "199769-1-0-8.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-9.wav (# 18)
# 	Splitting "199769-1-0-9.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 203956-1-0-0.wav (# 19)
# 	Splitting "203956-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 204765-1-0-0.wav (# 20)
# 	Splitting "204765-1-0-0.wav" into 2 1-second part(s)
# Currently extracting features in "car_horn" from 2937-1-0-0.wav (# 21)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 6984-1-0-0.wav (# 21)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 7389-1-0-1.wav (# 21)
# 	Splitting "7389-1-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-0-2.wav (# 22)
# 	Splitting "7389-1-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-0-3.wav (# 23)
# 	Splitting "7389-1-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-0-4.wav (# 24)
# 	Splitting "7389-1-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-0-5.wav (# 25)
# 	Splitting "7389-1-0-5.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-0-6.wav (# 26)
# 	Splitting "7389-1-0-6.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-0-7.wav (# 27)
# 	Splitting "7389-1-0-7.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-1-0.wav (# 28)
# 	Splitting "7389-1-1-0.wav" into 3 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-2-0.wav (# 29)
# 	Splitting "7389-1-2-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-2-1.wav (# 30)
# 	Splitting "7389-1-2-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-2-2.wav (# 31)
# 	Splitting "7389-1-2-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-2-3.wav (# 32)
# 	Splitting "7389-1-2-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-3-0.wav (# 33)
# 	Splitting "7389-1-3-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-3-1.wav (# 34)
# 	Splitting "7389-1-3-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-3-2.wav (# 35)
# 	Splitting "7389-1-3-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-3-3.wav (# 36)
# 	Splitting "7389-1-3-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-3-4.wav (# 37)
# 	Splitting "7389-1-3-4.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-3-5.wav (# 38)
# 	Splitting "7389-1-3-5.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-4-0.wav (# 39)
# 	Splitting "7389-1-4-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-4-1.wav (# 40)
# 	Splitting "7389-1-4-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-4-2.wav (# 41)
# 	Splitting "7389-1-4-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-4-3.wav (# 42)
# 	Splitting "7389-1-4-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-4-4.wav (# 43)
# 	Splitting "7389-1-4-4.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-4-5.wav (# 44)
# 	Splitting "7389-1-4-5.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-4-6.wav (# 45)
# 	Splitting "7389-1-4-6.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-4-7.wav (# 46)
# 	Splitting "7389-1-4-7.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-4-8.wav (# 47)
# 	Splitting "7389-1-4-8.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 13579-2-0-15.wav (# 1)
# 	Splitting "13579-2-0-15.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 13579-2-0-16.wav (# 2)
# 	Splitting "13579-2-0-16.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 13579-2-0-17.wav (# 3)
# 	Splitting "13579-2-0-17.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 13579-2-0-2.wav (# 4)
# 	Splitting "13579-2-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 13579-2-0-38.wav (# 5)
# 	Splitting "13579-2-0-38.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 13579-2-0-48.wav (# 6)
# 	Splitting "13579-2-0-48.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 13579-2-0-53.wav (# 7)
# 	Splitting "13579-2-0-53.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 13579-2-0-62.wav (# 8)
# 	Splitting "13579-2-0-62.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 14470-2-0-10.wav (# 9)
# 	Splitting "14470-2-0-10.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 14470-2-0-14.wav (# 10)
# 	Splitting "14470-2-0-14.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 14470-2-0-21.wav (# 11)
# 	Splitting "14470-2-0-21.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 14470-2-0-4.wav (# 12)
# 	Splitting "14470-2-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 14470-2-0-56.wav (# 13)
# 	Splitting "14470-2-0-56.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 14470-2-0-65.wav (# 14)
# 	Splitting "14470-2-0-65.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 14470-2-0-70.wav (# 15)
# 	Splitting "14470-2-0-70.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 14470-2-0-72.wav (# 16)
# 	Splitting "14470-2-0-72.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 207213-2-0-109.wav (# 17)
# 	Splitting "207213-2-0-109.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 207213-2-0-130.wav (# 18)
# 	Splitting "207213-2-0-130.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 207213-2-0-134.wav (# 19)
# 	Splitting "207213-2-0-134.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 207213-2-0-85.wav (# 20)
# 	Splitting "207213-2-0-85.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 207214-2-0-126.wav (# 21)
# 	Splitting "207214-2-0-126.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 207214-2-0-26.wav (# 22)
# 	Splitting "207214-2-0-26.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 207214-2-0-3.wav (# 23)
# 	Splitting "207214-2-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 207214-2-0-31.wav (# 24)
# 	Splitting "207214-2-0-31.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 207214-2-0-54.wav (# 25)
# 	Splitting "207214-2-0-54.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 207214-2-0-62.wav (# 26)
# 	Splitting "207214-2-0-62.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 207214-2-0-63.wav (# 27)
# 	Splitting "207214-2-0-63.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 207214-2-0-68.wav (# 28)
# 	Splitting "207214-2-0-68.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 207216-2-0-112.wav (# 29)
# 	Splitting "207216-2-0-112.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 207216-2-0-119.wav (# 30)
# 	Splitting "207216-2-0-119.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 207216-2-0-128.wav (# 31)
# 	Splitting "207216-2-0-128.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 207216-2-0-130.wav (# 32)
# 	Splitting "207216-2-0-130.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 207216-2-0-137.wav (# 33)
# 	Splitting "207216-2-0-137.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 207216-2-0-22.wav (# 34)
# 	Splitting "207216-2-0-22.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 207216-2-0-43.wav (# 35)
# 	Splitting "207216-2-0-43.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 207216-2-0-66.wav (# 36)
# 	Splitting "207216-2-0-66.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 6902-2-0-12.wav (# 37)
# 	Splitting "6902-2-0-12.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 6902-2-0-18.wav (# 38)
# 	Splitting "6902-2-0-18.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 6902-2-0-26.wav (# 39)
# 	Splitting "6902-2-0-26.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 6902-2-0-4.wav (# 40)
# 	Splitting "6902-2-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 6902-2-0-5.wav (# 41)
# 	Splitting "6902-2-0-5.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 6902-2-0-7.wav (# 42)
# 	Splitting "6902-2-0-7.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 6902-2-0-9.wav (# 43)
# 	Splitting "6902-2-0-9.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 9223-2-0-10.wav (# 44)
# 	Splitting "9223-2-0-10.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 9223-2-0-15.wav (# 45)
# 	Splitting "9223-2-0-15.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 9223-2-0-17.wav (# 46)
# 	Splitting "9223-2-0-17.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 9223-2-0-2.wav (# 47)
# 	Splitting "9223-2-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 9223-2-0-4.wav (# 48)
# 	Splitting "9223-2-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 9223-2-0-5.wav (# 49)
# 	Splitting "9223-2-0-5.wav" into 4 1-second part(s)
# Currently extracting features in "children_playing" from 9223-2-0-9.wav (# 50)
# 	Splitting "9223-2-0-9.wav" into 4 1-second part(s)
# Currently extracting features in "dog_bark" from 204773-3-9-1.wav (# 1)
# 	Splitting "204773-3-9-1.wav" into 4 1-second part(s)
# Currently extracting features in "dog_bark" from 204919-3-0-0.wav (# 2)
# 	Splitting "204919-3-0-0.wav" into 2 1-second part(s)
# Currently extracting features in "dog_bark" from 204919-3-1-0.wav (# 3)
# 	Splitting "204919-3-1-0.wav" into 4 1-second part(s)
# Currently extracting features in "dog_bark" from 204919-3-3-0.wav (# 4)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 204919-3-4-0.wav (# 4)
# 	Splitting "204919-3-4-0.wav" into 1 1-second part(s)
# Currently extracting features in "dog_bark" from 207124-3-0-0.wav (# 5)
# 	Splitting "207124-3-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "dog_bark" from 207124-3-1-0.wav (# 6)
# 	Splitting "207124-3-1-0.wav" into 2 1-second part(s)
# Currently extracting features in "dog_bark" from 207124-3-2-0.wav (# 7)
# 	Splitting "207124-3-2-0.wav" into 4 1-second part(s)
# Currently extracting features in "dog_bark" from 207369-3-0-0.wav (# 8)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 207962-3-0-0.wav (# 8)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 207962-3-1-0.wav (# 8)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 207962-3-2-0.wav (# 8)
# 	Splitting "207962-3-2-0.wav" into 1 1-second part(s)
# Currently extracting features in "dog_bark" from 208030-3-0-0.wav (# 9)
# 	Splitting "208030-3-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "dog_bark" from 208030-3-1-0.wav (# 10)
# 	Splitting "208030-3-1-0.wav" into 1 1-second part(s)
# Currently extracting features in "dog_bark" from 208030-3-2-0.wav (# 11)
# 	Splitting "208030-3-2-0.wav" into 1 1-second part(s)
# Currently extracting features in "dog_bark" from 208030-3-4-0.wav (# 12)
# 	Splitting "208030-3-4-0.wav" into 3 1-second part(s)
# Currently extracting features in "dog_bark" from 209672-3-0-0.wav (# 13)
# 	Splitting "209672-3-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "dog_bark" from 209672-3-3-0.wav (# 14)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 209672-3-6-0.wav (# 14)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 209672-3-8-0.wav (# 14)
# 	Splitting "209672-3-8-0.wav" into 1 1-second part(s)
# Currently extracting features in "dog_bark" from 344-3-0-0.wav (# 15)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 344-3-1-0.wav (# 15)
# 	Splitting "344-3-1-0.wav" into 1 1-second part(s)
# Currently extracting features in "dog_bark" from 344-3-4-0.wav (# 16)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 344-3-5-0.wav (# 16)
# 	Splitting "344-3-5-0.wav" into 1 1-second part(s)
# Currently extracting features in "dog_bark" from 4201-3-0-0.wav (# 17)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 4201-3-1-0.wav (# 17)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 4201-3-2-0.wav (# 17)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 4201-3-3-0.wav (# 17)
# 	Splitting "4201-3-3-0.wav" into 1 1-second part(s)
# Currently extracting features in "dog_bark" from 4910-3-0-0.wav (# 18)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 4911-3-0-0.wav (# 18)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 4912-3-0-0.wav (# 18)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 4912-3-1-0.wav (# 18)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 4912-3-2-0.wav (# 18)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 4912-3-3-0.wav (# 18)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 4918-3-0-0.wav (# 18)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 4918-3-1-0.wav (# 18)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 4918-3-3-0.wav (# 18)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 4918-3-4-0.wav (# 18)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 7383-3-0-0.wav (# 18)
# 	Splitting "7383-3-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "dog_bark" from 7383-3-0-1.wav (# 19)
# 	Splitting "7383-3-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "dog_bark" from 7383-3-1-0.wav (# 20)
# 	Splitting "7383-3-1-0.wav" into 4 1-second part(s)
# Currently extracting features in "dog_bark" from 7913-3-0-0.wav (# 21)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 7913-3-1-0.wav (# 21)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 7913-3-2-0.wav (# 21)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 7913-3-3-0.wav (# 21)
# *ignored, file under 1 second long*
# Currently extracting features in "dog_bark" from 7965-3-11-0.wav (# 21)
# 	Splitting "7965-3-11-0.wav" into 1 1-second part(s)
# Currently extracting features in "dog_bark" from 7965-3-16-0.wav (# 22)
# 	Splitting "7965-3-16-0.wav" into 1 1-second part(s)
# Currently extracting features in "dog_bark" from 7965-3-22-0.wav (# 23)
# 	Splitting "7965-3-22-0.wav" into 2 1-second part(s)
# Currently extracting features in "dog_bark" from 7965-3-3-0.wav (# 24)
# 	Splitting "7965-3-3-0.wav" into 1 1-second part(s)
# Currently extracting features in "dog_bark" from 7975-3-0-0.wav (# 25)
# 	Splitting "7975-3-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 14110-4-0-0.wav (# 1)
# 	Splitting "14110-4-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 14110-4-0-1.wav (# 2)
# 	Splitting "14110-4-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 14110-4-0-2.wav (# 3)
# 	Splitting "14110-4-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 14111-4-0-0.wav (# 4)
# 	Splitting "14111-4-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 14111-4-0-1.wav (# 5)
# 	Splitting "14111-4-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 14111-4-0-2.wav (# 6)
# 	Splitting "14111-4-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 14111-4-0-3.wav (# 7)
# 	Splitting "14111-4-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 14111-4-0-4.wav (# 8)
# 	Splitting "14111-4-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 14111-4-0-5.wav (# 9)
# 	Splitting "14111-4-0-5.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 14111-4-0-6.wav (# 10)
# 	Splitting "14111-4-0-6.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 14111-4-0-7.wav (# 11)
# 	Splitting "14111-4-0-7.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 14113-4-0-0.wav (# 12)
# 	Splitting "14113-4-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 14113-4-0-1.wav (# 13)
# 	Splitting "14113-4-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 14114-4-0-0.wav (# 14)
# 	Splitting "14114-4-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 14114-4-0-1.wav (# 15)
# 	Splitting "14114-4-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 14114-4-0-2.wav (# 16)
# 	Splitting "14114-4-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 14114-4-0-3.wav (# 17)
# 	Splitting "14114-4-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 14115-4-0-0.wav (# 18)
# 	Splitting "14115-4-0-0.wav" into 2 1-second part(s)
# Currently extracting features in "drilling" from 17913-4-0-0.wav (# 19)
# 	Splitting "17913-4-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 17913-4-0-1.wav (# 20)
# 	Splitting "17913-4-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 17913-4-0-2.wav (# 21)
# 	Splitting "17913-4-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 17913-4-1-0.wav (# 22)
# 	Splitting "17913-4-1-0.wav" into 1 1-second part(s)
# Currently extracting features in "drilling" from 17913-4-2-0.wav (# 23)
# 	Splitting "17913-4-2-0.wav" into 1 1-second part(s)
# Currently extracting features in "drilling" from 19007-4-0-0.wav (# 24)
# 	Splitting "19007-4-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 199929-4-2-0.wav (# 25)
# 	Splitting "199929-4-2-0.wav" into 3 1-second part(s)
# Currently extracting features in "drilling" from 205610-4-0-0.wav (# 26)
# 	Splitting "205610-4-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 205610-4-0-1.wav (# 27)
# 	Splitting "205610-4-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 205610-4-0-2.wav (# 28)
# 	Splitting "205610-4-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 205610-4-0-3.wav (# 29)
# 	Splitting "205610-4-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 205610-4-0-4.wav (# 30)
# 	Splitting "205610-4-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 205610-4-0-5.wav (# 31)
# 	Splitting "205610-4-0-5.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 205874-4-0-0.wav (# 32)
# 	Splitting "205874-4-0-0.wav" into 2 1-second part(s)
# Currently extracting features in "drilling" from 205874-4-1-0.wav (# 33)
# 	Splitting "205874-4-1-0.wav" into 1 1-second part(s)
# Currently extracting features in "drilling" from 205874-4-10-0.wav (# 34)
# 	Splitting "205874-4-10-0.wav" into 1 1-second part(s)
# Currently extracting features in "drilling" from 205874-4-11-0.wav (# 35)
# *ignored, file under 1 second long*
# Currently extracting features in "drilling" from 205874-4-2-0.wav (# 35)
# 	Splitting "205874-4-2-0.wav" into 1 1-second part(s)
# Currently extracting features in "drilling" from 205874-4-3-0.wav (# 36)
# *ignored, file under 1 second long*
# Currently extracting features in "drilling" from 205874-4-4-0.wav (# 36)
# *ignored, file under 1 second long*
# Currently extracting features in "drilling" from 205874-4-5-0.wav (# 36)
# *ignored, file under 1 second long*
# Currently extracting features in "drilling" from 205874-4-6-0.wav (# 36)
# 	Splitting "205874-4-6-0.wav" into 1 1-second part(s)
# Currently extracting features in "drilling" from 205874-4-7-0.wav (# 37)
# 	Splitting "205874-4-7-0.wav" into 3 1-second part(s)
# Currently extracting features in "drilling" from 205874-4-8-0.wav (# 38)
# 	Splitting "205874-4-8-0.wav" into 1 1-second part(s)
# Currently extracting features in "drilling" from 205874-4-9-0.wav (# 39)
# 	Splitting "205874-4-9-0.wav" into 1 1-second part(s)
# Currently extracting features in "drilling" from 205878-4-0-0.wav (# 40)
# 	Splitting "205878-4-0-0.wav" into 3 1-second part(s)
# Currently extracting features in "drilling" from 22962-4-0-0.wav (# 41)
# 	Splitting "22962-4-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 22962-4-0-1.wav (# 42)
# 	Splitting "22962-4-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 518-4-0-0.wav (# 43)
# 	Splitting "518-4-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 518-4-0-1.wav (# 44)
# 	Splitting "518-4-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 518-4-0-2.wav (# 45)
# 	Splitting "518-4-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "drilling" from 518-4-0-3.wav (# 46)
# 	Splitting "518-4-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 12812-5-0-0.wav (# 1)
# 	Splitting "12812-5-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 12812-5-0-1.wav (# 2)
# 	Splitting "12812-5-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 12812-5-0-2.wav (# 3)
# 	Splitting "12812-5-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 15544-5-0-0.wav (# 4)
# 	Splitting "15544-5-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 15544-5-0-1.wav (# 5)
# 	Splitting "15544-5-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 15544-5-0-10.wav (# 6)
# 	Splitting "15544-5-0-10.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 15544-5-0-11.wav (# 7)
# 	Splitting "15544-5-0-11.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 15544-5-0-12.wav (# 8)
# 	Splitting "15544-5-0-12.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 15544-5-0-13.wav (# 9)
# 	Splitting "15544-5-0-13.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 15544-5-0-14.wav (# 10)
# 	Splitting "15544-5-0-14.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 15544-5-0-15.wav (# 11)
# 	Splitting "15544-5-0-15.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 15544-5-0-16.wav (# 12)
# 	Splitting "15544-5-0-16.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 15544-5-0-17.wav (# 13)
# 	Splitting "15544-5-0-17.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 15544-5-0-18.wav (# 14)
# 	Splitting "15544-5-0-18.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 15544-5-0-19.wav (# 15)
# 	Splitting "15544-5-0-19.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 15544-5-0-2.wav (# 16)
# 	Splitting "15544-5-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 15544-5-0-3.wav (# 17)
# 	Splitting "15544-5-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 15544-5-0-4.wav (# 18)
# 	Splitting "15544-5-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 15544-5-0-5.wav (# 19)
# 	Splitting "15544-5-0-5.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 15544-5-0-6.wav (# 20)
# 	Splitting "15544-5-0-6.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 15544-5-0-7.wav (# 21)
# 	Splitting "15544-5-0-7.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 15544-5-0-8.wav (# 22)
# 	Splitting "15544-5-0-8.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 15544-5-0-9.wav (# 23)
# 	Splitting "15544-5-0-9.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 16692-5-0-0.wav (# 24)
# 	Splitting "16692-5-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 209992-5-2-100.wav (# 25)
# 	Splitting "209992-5-2-100.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 209992-5-2-114.wav (# 26)
# 	Splitting "209992-5-2-114.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 209992-5-2-115.wav (# 27)
# 	Splitting "209992-5-2-115.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 209992-5-2-116.wav (# 28)
# 	Splitting "209992-5-2-116.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 209992-5-2-131.wav (# 29)
# 	Splitting "209992-5-2-131.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 209992-5-2-137.wav (# 30)
# 	Splitting "209992-5-2-137.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 209992-5-2-138.wav (# 31)
# 	Splitting "209992-5-2-138.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 209992-5-2-77.wav (# 32)
# 	Splitting "209992-5-2-77.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 209992-5-2-79.wav (# 33)
# 	Splitting "209992-5-2-79.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 209992-5-2-81.wav (# 34)
# 	Splitting "209992-5-2-81.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 209992-5-2-82.wav (# 35)
# 	Splitting "209992-5-2-82.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 209992-5-2-87.wav (# 36)
# 	Splitting "209992-5-2-87.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 209992-5-2-91.wav (# 37)
# 	Splitting "209992-5-2-91.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 209992-5-3-22.wav (# 38)
# 	Splitting "209992-5-3-22.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 209992-5-3-5.wav (# 39)
# 	Splitting "209992-5-3-5.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 209992-5-3-6.wav (# 40)
# 	Splitting "209992-5-3-6.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 209992-5-4-1.wav (# 41)
# 	Splitting "209992-5-4-1.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 209992-5-4-15.wav (# 42)
# 	Splitting "209992-5-4-15.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 209992-5-4-17.wav (# 43)
# 	Splitting "209992-5-4-17.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 209992-5-4-3.wav (# 44)
# 	Splitting "209992-5-4-3.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 6988-5-0-0.wav (# 45)
# 	Splitting "6988-5-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 6988-5-0-1.wav (# 46)
# 	Splitting "6988-5-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 6988-5-0-2.wav (# 47)
# 	Splitting "6988-5-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 6988-5-0-3.wav (# 48)
# 	Splitting "6988-5-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 6988-5-0-4.wav (# 49)
# 	Splitting "6988-5-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "engine_idling" from 6988-5-0-5.wav (# 50)
# 	Splitting "6988-5-0-5.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 14772-7-0-0.wav (# 1)
# 	Splitting "14772-7-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "jackhammer" from 14772-7-1-0.wav (# 2)
# 	Splitting "14772-7-1-0.wav" into 1 1-second part(s)
# Currently extracting features in "jackhammer" from 14772-7-2-0.wav (# 3)
# 	Splitting "14772-7-2-0.wav" into 1 1-second part(s)
# Currently extracting features in "jackhammer" from 14772-7-3-0.wav (# 4)
# 	Splitting "14772-7-3-0.wav" into 1 1-second part(s)
# Currently extracting features in "jackhammer" from 14772-7-4-0.wav (# 5)
# 	Splitting "14772-7-4-0.wav" into 1 1-second part(s)
# Currently extracting features in "jackhammer" from 14772-7-5-0.wav (# 6)
# 	Splitting "14772-7-5-0.wav" into 2 1-second part(s)
# Currently extracting features in "jackhammer" from 14772-7-6-0.wav (# 7)
# 	Splitting "14772-7-6-0.wav" into 2 1-second part(s)
# Currently extracting features in "jackhammer" from 14772-7-7-0.wav (# 8)
# 	Splitting "14772-7-7-0.wav" into 2 1-second part(s)
# Currently extracting features in "jackhammer" from 14772-7-8-0.wav (# 9)
# 	Splitting "14772-7-8-0.wav" into 1 1-second part(s)
# Currently extracting features in "jackhammer" from 14772-7-9-0.wav (# 10)
# 	Splitting "14772-7-9-0.wav" into 3 1-second part(s)
# Currently extracting features in "jackhammer" from 203929-7-10-0.wav (# 11)
# 	Splitting "203929-7-10-0.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 203929-7-10-1.wav (# 12)
# 	Splitting "203929-7-10-1.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 203929-7-10-2.wav (# 13)
# 	Splitting "203929-7-10-2.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 203929-7-7-14.wav (# 14)
# 	Splitting "203929-7-7-14.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 203929-7-7-15.wav (# 15)
# 	Splitting "203929-7-7-15.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 203929-7-7-16.wav (# 16)
# 	Splitting "203929-7-7-16.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 203929-7-8-0.wav (# 17)
# 	Splitting "203929-7-8-0.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 203929-7-9-0.wav (# 18)
# 	Splitting "203929-7-9-0.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 203929-7-9-11.wav (# 19)
# 	Splitting "203929-7-9-11.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 203929-7-9-12.wav (# 20)
# 	Splitting "203929-7-9-12.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 203929-7-9-15.wav (# 21)
# 	Splitting "203929-7-9-15.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 203929-7-9-17.wav (# 22)
# 	Splitting "203929-7-9-17.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 203929-7-9-18.wav (# 23)
# 	Splitting "203929-7-9-18.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 203929-7-9-19.wav (# 24)
# 	Splitting "203929-7-9-19.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 203929-7-9-20.wav (# 25)
# 	Splitting "203929-7-9-20.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 203929-7-9-24.wav (# 26)
# 	Splitting "203929-7-9-24.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 203929-7-9-4.wav (# 27)
# 	Splitting "203929-7-9-4.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 203929-7-9-6.wav (# 28)
# 	Splitting "203929-7-9-6.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 203929-7-9-8.wav (# 29)
# 	Splitting "203929-7-9-8.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 203929-7-9-9.wav (# 30)
# 	Splitting "203929-7-9-9.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 22883-7-1-0.wav (# 31)
# 	Splitting "22883-7-1-0.wav" into 1 1-second part(s)
# Currently extracting features in "jackhammer" from 22883-7-10-0.wav (# 32)
# 	Splitting "22883-7-10-0.wav" into 2 1-second part(s)
# Currently extracting features in "jackhammer" from 22883-7-11-0.wav (# 33)
# 	Splitting "22883-7-11-0.wav" into 2 1-second part(s)
# Currently extracting features in "jackhammer" from 22883-7-17-2.wav (# 34)
# 	Splitting "22883-7-17-2.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 22883-7-17-4.wav (# 35)
# 	Splitting "22883-7-17-4.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 22883-7-17-5.wav (# 36)
# 	Splitting "22883-7-17-5.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 22883-7-18-0.wav (# 37)
# 	Splitting "22883-7-18-0.wav" into 2 1-second part(s)
# Currently extracting features in "jackhammer" from 22883-7-19-0.wav (# 38)
# 	Splitting "22883-7-19-0.wav" into 3 1-second part(s)
# Currently extracting features in "jackhammer" from 22883-7-21-0.wav (# 39)
# 	Splitting "22883-7-21-0.wav" into 2 1-second part(s)
# Currently extracting features in "jackhammer" from 22883-7-23-0.wav (# 40)
# 	Splitting "22883-7-23-0.wav" into 3 1-second part(s)
# Currently extracting features in "jackhammer" from 22883-7-24-0.wav (# 41)
# 	Splitting "22883-7-24-0.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 22883-7-27-0.wav (# 42)
# *ignored, file under 1 second long*
# Currently extracting features in "jackhammer" from 22883-7-28-0.wav (# 42)
# 	Splitting "22883-7-28-0.wav" into 1 1-second part(s)
# Currently extracting features in "jackhammer" from 22883-7-29-2.wav (# 43)
# 	Splitting "22883-7-29-2.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 22883-7-3-0.wav (# 44)
# 	Splitting "22883-7-3-0.wav" into 1 1-second part(s)
# Currently extracting features in "jackhammer" from 22883-7-33-0.wav (# 45)
# 	Splitting "22883-7-33-0.wav" into 1 1-second part(s)
# Currently extracting features in "jackhammer" from 22883-7-34-0.wav (# 46)
# 	Splitting "22883-7-34-0.wav" into 1 1-second part(s)
# Currently extracting features in "jackhammer" from 22883-7-35-2.wav (# 47)
# 	Splitting "22883-7-35-2.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 22883-7-35-3.wav (# 48)
# 	Splitting "22883-7-35-3.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 22883-7-7-0.wav (# 49)
# 	Splitting "22883-7-7-0.wav" into 4 1-second part(s)
# Currently extracting features in "jackhammer" from 22883-7-9-0.wav (# 50)
# *ignored, file under 1 second long*
# Currently extracting features in "street_music" from 14385-9-0-10.wav (# 1)
# 	Splitting "14385-9-0-10.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 14385-9-0-11.wav (# 2)
# 	Splitting "14385-9-0-11.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 14385-9-0-13.wav (# 3)
# 	Splitting "14385-9-0-13.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 14385-9-0-14.wav (# 4)
# 	Splitting "14385-9-0-14.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 14385-9-0-17.wav (# 5)
# 	Splitting "14385-9-0-17.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 14385-9-0-21.wav (# 6)
# 	Splitting "14385-9-0-21.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 14386-9-0-11.wav (# 7)
# 	Splitting "14386-9-0-11.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 14386-9-0-16.wav (# 8)
# 	Splitting "14386-9-0-16.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 14386-9-0-17.wav (# 9)
# 	Splitting "14386-9-0-17.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 14386-9-0-2.wav (# 10)
# 	Splitting "14386-9-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 14386-9-0-20.wav (# 11)
# 	Splitting "14386-9-0-20.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 14386-9-0-6.wav (# 12)
# 	Splitting "14386-9-0-6.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 14387-9-0-11.wav (# 13)
# 	Splitting "14387-9-0-11.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 14387-9-0-12.wav (# 14)
# 	Splitting "14387-9-0-12.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 14387-9-0-15.wav (# 15)
# 	Splitting "14387-9-0-15.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 14387-9-0-16.wav (# 16)
# 	Splitting "14387-9-0-16.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 14387-9-0-7.wav (# 17)
# 	Splitting "14387-9-0-7.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 196384-9-0-18.wav (# 18)
# 	Splitting "196384-9-0-18.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 196384-9-0-27.wav (# 19)
# 	Splitting "196384-9-0-27.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 202334-9-0-105.wav (# 20)
# 	Splitting "202334-9-0-105.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 202334-9-0-106.wav (# 21)
# 	Splitting "202334-9-0-106.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 202334-9-0-137.wav (# 22)
# 	Splitting "202334-9-0-137.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 202334-9-0-202.wav (# 23)
# 	Splitting "202334-9-0-202.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 202334-9-0-63.wav (# 24)
# 	Splitting "202334-9-0-63.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 202334-9-0-88.wav (# 25)
# 	Splitting "202334-9-0-88.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 203424-9-0-15.wav (# 26)
# 	Splitting "203424-9-0-15.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 203424-9-0-18.wav (# 27)
# 	Splitting "203424-9-0-18.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 203424-9-0-26.wav (# 28)
# 	Splitting "203424-9-0-26.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 203424-9-0-34.wav (# 29)
# 	Splitting "203424-9-0-34.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 203424-9-0-4.wav (# 30)
# 	Splitting "203424-9-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 203424-9-0-46.wav (# 31)
# 	Splitting "203424-9-0-46.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 203654-9-0-15.wav (# 32)
# 	Splitting "203654-9-0-15.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 203654-9-0-28.wav (# 33)
# 	Splitting "203654-9-0-28.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 203654-9-0-39.wav (# 34)
# 	Splitting "203654-9-0-39.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 203654-9-0-42.wav (# 35)
# 	Splitting "203654-9-0-42.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 203654-9-0-60.wav (# 36)
# 	Splitting "203654-9-0-60.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 203654-9-0-8.wav (# 37)
# 	Splitting "203654-9-0-8.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 6508-9-0-1.wav (# 38)
# 	Splitting "6508-9-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 6508-9-0-2.wav (# 39)
# 	Splitting "6508-9-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 6508-9-0-3.wav (# 40)
# 	Splitting "6508-9-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 6508-9-0-4.wav (# 41)
# 	Splitting "6508-9-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 6508-9-0-6.wav (# 42)
# 	Splitting "6508-9-0-6.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 6508-9-1-0.wav (# 43)
# 	Splitting "6508-9-1-0.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 7390-9-0-0.wav (# 44)
# 	Splitting "7390-9-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 7390-9-0-3.wav (# 45)
# 	Splitting "7390-9-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 7390-9-0-6.wav (# 46)
# 	Splitting "7390-9-0-6.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 7390-9-0-9.wav (# 47)
# 	Splitting "7390-9-0-9.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 7390-9-1-11.wav (# 48)
# 	Splitting "7390-9-1-11.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 7390-9-1-12.wav (# 49)
# 	Splitting "7390-9-1-12.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 7390-9-1-5.wav (# 50)
# 	Splitting "7390-9-1-5.wav" into 4 1-second part(s)
# ----- done. -----
# Total file count: 324
# Files ignored: 33
# Extracted 1132 windows from 291 Files
# Shape of dataframe: (1132, 48, 21)

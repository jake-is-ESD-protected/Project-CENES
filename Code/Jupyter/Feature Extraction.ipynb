# %% [markdown]
# # Feature Extraction
#
# Since the filters have been explored, the data displayed in spectrograms can now be written to `csv`-files for later training of the NN. The amount of data per soundfile is calculated with the following formula:
#
# ```
# size_in_b = n_frames * n_bands * sizeof(float32)
# ```
#
# This is one of the major strenghts of this method: instead of storing `512` bins `1024` times per second, the octave bank only creates `31` bins `24` times a second.

# %%
import os
from octafilt3r import filter as o3f
import librosa as lr
import numpy as np
import json


user_mode = False

# %%
if user_mode == 'y':
    txt_name = input("give your storage-file a name: ") + '.txt'
else:
    txt_name = "th_oct_feature.txt"

std_txt_fp = "Datasets/Feature_extraction/th_oct_coeffs.txt"
source_dir = 'Datasets/UrbanSound8k_augmented/'

fs = 48000                              # sample rate
fmin = 100                              # lowest f of interest
fmax = 12800                            # highest f of interest
oct_bw_ratio = 1/3                      # octave / amount of subdivisions
order = 8                               # order of octave filters

n_coeffs_p_section = 6                  # constant, definition of sos-matrix
n_sections = int(order/2)               # number of biquads (order 2 filters)
dec_stages = 4                          # number of decimations across bank
dec_ord = 10                            # order of decimation AA-filters

frame_size = 1000                      # framing size
fps = int(fs / frame_size)
window_size = fs * 1
max_dur = 5                            # max duration of sound in s
_, _, _, n_bands = o3f._gen_fc_fl_fu(fmax, fmin, oct_bw_ratio)

param_dict_fp = 'param_dict.json'
param_dict = {  
    "txt name":txt_name,
    "std_txt_fp":std_txt_fp,
    "source_dir":source_dir,
    "fs":fs,
    "fmin":fmin,
    "fmax":fmax,
    "oct_bw_ratio":oct_bw_ratio,
    "order":order,
    "n_coeffs_p_section":n_coeffs_p_section,
    "n_sections":n_sections,
    "dec_stages":dec_stages,
    "dec_ord":dec_ord,
    "frame_size": frame_size,
    "fps":fps,
    "window_size": window_size,
    "max_dur":max_dur,
    "n_bands":n_bands
}

with open(param_dict_fp, 'w') as f:
    json.dump(param_dict, f)

# %%
files_ignored = 0
tot_cnt = 0

df = []
labels = []
for class_ in os.listdir(source_dir):
    cnt = 1
    for filename in os.listdir(f'{source_dir}{class_}'):

        print(f'Currently extracting features in "{class_}" from {filename} (# {cnt})')

        wav = f'{source_dir}{class_}/{filename}'
        y, sr = lr.load(wav, sr=fs, mono=True, duration=max_dur)

        wins = int(len(y)/window_size)
        if wins == 0:
            files_ignored += 1
            print('*ignored, file under 1 second long*')
            continue    # skip files which are shorter than 1s

        # obtain features of whole file
        feats, fcs = o3f.rolling_oct_bank(y, fs, ratio=oct_bw_ratio, fmax=fmax, fmin=fmin, frame_size=frame_size, n_decimations=dec_stages)

        print(f'\tSplitting "{filename}" into {wins} 1-second part(s)')
        for win in range(wins):    # ignore parts of file which is not in a full window
            cur_feats = feats[fps * win:fps * (win + 1)]
            df.append(cur_feats)
            labels.append(class_)
        cnt += 1

    tot_cnt += cnt

df = np.dstack(df)
df = np.transpose(df, (2, 0, 1))

df_2d = df.reshape(df.shape[0], -1)
np.savetxt("Datasets/Feature_extraction/th_oct_feature.txt", df_2d)
with open("Datasets/Feature_extraction/labels.txt", "w") as f:
    for i in labels:
        f.writelines(i + '\n')


print(f'----- done. -----\nTotal file count: {tot_cnt}\nFiles ignored: {files_ignored}\nExtracted {len(df)} windows from {tot_cnt-files_ignored} Files')
print(f'Shape of dataframe: {df.shape}')
# Out:
# Currently extracting features in "car_horn" from 100648-1-0-0.wav (# 1)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 100648-1-1-0.wav (# 1)
# 	Splitting "100648-1-1-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 100648-1-2-0.wav (# 2)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 100648-1-3-0.wav (# 2)
# 	Splitting "100648-1-3-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 100648-1-4-0.wav (# 3)
# 	Splitting "100648-1-4-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 107090-1-0-0.wav (# 4)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 107090-1-1-0.wav (# 4)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 117536-1-0-0.wav (# 4)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 118070-1-0-0.wav (# 4)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 118496-1-0-0.wav (# 4)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 118496-1-1-0.wav (# 4)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 121299-1-0-0.wav (# 4)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 125520-1-0-0.wav (# 4)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 125520-1-1-0.wav (# 4)
# 	Splitting "125520-1-1-0.wav" into 2 1-second part(s)
# Currently extracting features in "car_horn" from 125520-1-2-0.wav (# 5)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 125520-1-3-0.wav (# 5)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 125520-1-4-0.wav (# 5)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 128465-1-0-0.wav (# 5)
# 	Splitting "128465-1-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 128465-1-0-1.wav (# 6)
# 	Splitting "128465-1-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 128465-1-0-2.wav (# 7)
# 	Splitting "128465-1-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 128465-1-0-3.wav (# 8)
# 	Splitting "128465-1-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 128465-1-0-4.wav (# 9)
# 	Splitting "128465-1-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 128465-1-0-5.wav (# 10)
# 	Splitting "128465-1-0-5.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 128465-1-0-6.wav (# 11)
# 	Splitting "128465-1-0-6.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 128465-1-0-7.wav (# 12)
# 	Splitting "128465-1-0-7.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 128465-1-0-8.wav (# 13)
# 	Splitting "128465-1-0-8.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 132073-1-0-0.wav (# 14)
# 	Splitting "132073-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 132073-1-1-0.wav (# 15)
# 	Splitting "132073-1-1-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 132073-1-2-0.wav (# 16)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 132073-1-3-0.wav (# 16)
# 	Splitting "132073-1-3-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 132073-1-4-0.wav (# 17)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 132073-1-5-0.wav (# 17)
# 	Splitting "132073-1-5-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 132073-1-6-0.wav (# 18)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 138465-1-0-0.wav (# 18)
# 	Splitting "138465-1-0-0.wav" into 3 1-second part(s)
# Currently extracting features in "car_horn" from 138468-1-0-0.wav (# 19)
# 	Splitting "138468-1-0-0.wav" into 3 1-second part(s)
# Currently extracting features in "car_horn" from 143115-1-0-0.wav (# 20)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 143115-1-1-0.wav (# 20)
# 	Splitting "143115-1-1-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 143115-1-2-0.wav (# 21)
# 	Splitting "143115-1-2-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 143115-1-3-0.wav (# 22)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 143115-1-4-0.wav (# 22)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 14524-1-0-0.wav (# 22)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 145577-1-0-0.wav (# 22)
# 	Splitting "145577-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 151359-1-0-0.wav (# 23)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 151359-1-1-0.wav (# 23)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 151359-1-2-0.wav (# 23)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 151359-1-3-0.wav (# 23)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 153057-1-0-0.wav (# 23)
# 	Splitting "153057-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 155129-1-0-0.wav (# 24)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 155129-1-1-0.wav (# 24)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 155129-1-2-0.wav (# 24)
# 	Splitting "155129-1-2-0.wav" into 2 1-second part(s)
# Currently extracting features in "car_horn" from 155130-1-0-0.wav (# 25)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 155130-1-1-0.wav (# 25)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 155234-1-0-0.wav (# 25)
# 	Splitting "155234-1-0-0.wav" into 2 1-second part(s)
# Currently extracting features in "car_horn" from 155283-1-0-0.wav (# 26)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 155283-1-1-0.wav (# 26)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 156091-1-0-0.wav (# 26)
# 	Splitting "156091-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 156194-1-0-0.wav (# 27)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 161010-1-0-0.wav (# 27)
# 	Splitting "161010-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 161010-1-1-0.wav (# 28)
# 	Splitting "161010-1-1-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 161010-1-2-0.wav (# 29)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 161010-1-3-0.wav (# 29)
# 	Splitting "161010-1-3-0.wav" into 2 1-second part(s)
# Currently extracting features in "car_horn" from 162540-1-0-0.wav (# 30)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 162540-1-1-0.wav (# 30)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 162540-1-2-0.wav (# 30)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 162541-1-0-0.wav (# 30)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 162541-1-1-0.wav (# 30)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 162541-1-2-0.wav (# 30)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 162702-1-0-0.wav (# 30)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 162702-1-1-0.wav (# 30)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 162703-1-0-0.wav (# 30)
# 	Splitting "162703-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 162728-1-0-0.wav (# 31)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 164625-1-0-0.wav (# 31)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 164626-1-0-0.wav (# 31)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 164627-1-0-0.wav (# 31)
# 	Splitting "164627-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 170243-1-0-0.wav (# 32)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 17074-1-0-0.wav (# 32)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 17124-1-0-0.wav (# 32)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 171249-1-0-0.wav (# 32)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 171249-1-1-0.wav (# 32)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 171249-1-2-0.wav (# 32)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 17307-1-0-0.wav (# 32)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 174840-1-0-0.wav (# 32)
# 	Splitting "174840-1-0-0.wav" into 2 1-second part(s)
# Currently extracting features in "car_horn" from 174841-1-0-0.wav (# 33)
# 	Splitting "174841-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 175842-1-0-0.wav (# 34)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 175843-1-0-0.wav (# 34)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 175844-1-0-0.wav (# 34)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 175845-1-0-0.wav (# 34)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 175846-1-0-0.wav (# 34)
# 	Splitting "175846-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 175847-1-0-0.wav (# 35)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 175848-1-0-0.wav (# 35)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 175849-1-0-0.wav (# 35)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 175850-1-0-0.wav (# 35)
# 	Splitting "175850-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 175851-1-0-0.wav (# 36)
# 	Splitting "175851-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 175852-1-0-0.wav (# 37)
# 	Splitting "175852-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 175853-1-0-0.wav (# 38)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 175854-1-0-0.wav (# 38)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 175855-1-0-0.wav (# 38)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 175856-1-0-0.wav (# 38)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 175856-1-1-0.wav (# 38)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 175856-1-2-0.wav (# 38)
# 	Splitting "175856-1-2-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 176003-1-0-0.wav (# 39)
# 	Splitting "176003-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 176631-1-0-0.wav (# 40)
# 	Splitting "176631-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 176634-1-0-0.wav (# 41)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 176638-1-0-0.wav (# 41)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 176638-1-1-0.wav (# 41)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 178115-1-0-0.wav (# 41)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 178402-1-0-0.wav (# 41)
# 	Splitting "178402-1-0-0.wav" into 2 1-second part(s)
# Currently extracting features in "car_horn" from 179858-1-0-0.wav (# 42)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 179860-1-0-0.wav (# 42)
# 	Splitting "179860-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 179861-1-0-0.wav (# 43)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 179862-1-0-0.wav (# 43)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 179863-1-0-0.wav (# 43)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 179864-1-0-0.wav (# 43)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 179865-1-0-0.wav (# 43)
# 	Splitting "179865-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 179866-1-0-0.wav (# 44)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 179866-1-1-0.wav (# 44)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 179867-1-0-0.wav (# 44)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 179868-1-0-0.wav (# 44)
# 	Splitting "179868-1-0-0.wav" into 2 1-second part(s)
# Currently extracting features in "car_horn" from 180156-1-0-0.wav (# 45)
# 	Splitting "180156-1-0-0.wav" into 2 1-second part(s)
# Currently extracting features in "car_horn" from 180156-1-1-0.wav (# 46)
# 	Splitting "180156-1-1-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 180156-1-10-0.wav (# 47)
# 	Splitting "180156-1-10-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 180156-1-11-0.wav (# 48)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 180156-1-12-0.wav (# 48)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 180156-1-2-0.wav (# 48)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 180156-1-3-0.wav (# 48)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 180156-1-4-0.wav (# 48)
# 	Splitting "180156-1-4-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 180156-1-5-0.wav (# 49)
# 	Splitting "180156-1-5-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 180156-1-6-0.wav (# 50)
# 	Splitting "180156-1-6-0.wav" into 3 1-second part(s)
# Currently extracting features in "car_horn" from 180156-1-7-0.wav (# 51)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 180156-1-8-0.wav (# 51)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 180156-1-9-0.wav (# 51)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 182474-1-0-0.wav (# 51)
# 	Splitting "182474-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 183894-1-5-0.wav (# 52)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 183894-1-6-0.wav (# 52)
# 	Splitting "183894-1-6-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 183894-1-7-0.wav (# 53)
# 	Splitting "183894-1-7-0.wav" into 2 1-second part(s)
# Currently extracting features in "car_horn" from 183894-1-8-0.wav (# 54)
# 	Splitting "183894-1-8-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 183894-1-9-0.wav (# 55)
# 	Splitting "183894-1-9-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 184355-1-0-0.wav (# 56)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 185436-1-0-0.wav (# 56)
# 	Splitting "185436-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 185436-1-1-0.wav (# 57)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 185436-1-2-0.wav (# 57)
# 	Splitting "185436-1-2-0.wav" into 2 1-second part(s)
# Currently extracting features in "car_horn" from 185436-1-3-0.wav (# 58)
# 	Splitting "185436-1-3-0.wav" into 2 1-second part(s)
# Currently extracting features in "car_horn" from 185436-1-4-0.wav (# 59)
# 	Splitting "185436-1-4-0.wav" into 3 1-second part(s)
# Currently extracting features in "car_horn" from 185436-1-5-0.wav (# 60)
# 	Splitting "185436-1-5-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 185436-1-6-0.wav (# 61)
# 	Splitting "185436-1-6-0.wav" into 2 1-second part(s)
# Currently extracting features in "car_horn" from 185436-1-7-0.wav (# 62)
# 	Splitting "185436-1-7-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 18594-1-0-0.wav (# 63)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 18594-1-1-0.wav (# 63)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 18594-1-2-0.wav (# 63)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 18594-1-3-0.wav (# 63)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 18594-1-4-0.wav (# 63)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 18594-1-5-0.wav (# 63)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 18594-1-6-0.wav (# 63)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 187356-1-0-0.wav (# 63)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 187356-1-1-0.wav (# 63)
# 	Splitting "187356-1-1-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 187356-1-2-0.wav (# 64)
# 	Splitting "187356-1-2-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 187356-1-3-0.wav (# 65)
# 	Splitting "187356-1-3-0.wav" into 3 1-second part(s)
# Currently extracting features in "car_horn" from 187356-1-4-0.wav (# 66)
# 	Splitting "187356-1-4-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 187356-1-5-0.wav (# 67)
# 	Splitting "187356-1-5-0.wav" into 2 1-second part(s)
# Currently extracting features in "car_horn" from 187356-1-6-0.wav (# 68)
# 	Splitting "187356-1-6-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 18933-1-0-0.wav (# 69)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 19026-1-0-0.wav (# 69)
# 	Splitting "19026-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-0.wav (# 70)
# 	Splitting "199769-1-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-1.wav (# 71)
# 	Splitting "199769-1-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-10.wav (# 72)
# 	Splitting "199769-1-0-10.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-11.wav (# 73)
# 	Splitting "199769-1-0-11.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-12.wav (# 74)
# 	Splitting "199769-1-0-12.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-13.wav (# 75)
# 	Splitting "199769-1-0-13.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-14.wav (# 76)
# 	Splitting "199769-1-0-14.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-15.wav (# 77)
# 	Splitting "199769-1-0-15.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-16.wav (# 78)
# 	Splitting "199769-1-0-16.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-17.wav (# 79)
# 	Splitting "199769-1-0-17.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-18.wav (# 80)
# 	Splitting "199769-1-0-18.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-2.wav (# 81)
# 	Splitting "199769-1-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-3.wav (# 82)
# 	Splitting "199769-1-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-4.wav (# 83)
# 	Splitting "199769-1-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-5.wav (# 84)
# 	Splitting "199769-1-0-5.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-6.wav (# 85)
# 	Splitting "199769-1-0-6.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-7.wav (# 86)
# 	Splitting "199769-1-0-7.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-8.wav (# 87)
# 	Splitting "199769-1-0-8.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 199769-1-0-9.wav (# 88)
# 	Splitting "199769-1-0-9.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 203956-1-0-0.wav (# 89)
# 	Splitting "203956-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 204765-1-0-0.wav (# 90)
# 	Splitting "204765-1-0-0.wav" into 2 1-second part(s)
# Currently extracting features in "car_horn" from 24074-1-0-0.wav (# 91)
# 	Splitting "24074-1-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 24074-1-0-1.wav (# 92)
# 	Splitting "24074-1-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 24074-1-0-10.wav (# 93)
# 	Splitting "24074-1-0-10.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 24074-1-0-11.wav (# 94)
# 	Splitting "24074-1-0-11.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 24074-1-0-12.wav (# 95)
# 	Splitting "24074-1-0-12.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 24074-1-0-13.wav (# 96)
# 	Splitting "24074-1-0-13.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 24074-1-0-2.wav (# 97)
# 	Splitting "24074-1-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 24074-1-0-3.wav (# 98)
# 	Splitting "24074-1-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 24074-1-0-4.wav (# 99)
# 	Splitting "24074-1-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 24074-1-0-5.wav (# 100)
# 	Splitting "24074-1-0-5.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 24074-1-0-6.wav (# 101)
# 	Splitting "24074-1-0-6.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 24074-1-0-7.wav (# 102)
# 	Splitting "24074-1-0-7.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 24074-1-0-8.wav (# 103)
# 	Splitting "24074-1-0-8.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 24074-1-0-9.wav (# 104)
# 	Splitting "24074-1-0-9.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 24076-1-0-0.wav (# 105)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 24076-1-1-0.wav (# 105)
# 	Splitting "24076-1-1-0.wav" into 3 1-second part(s)
# Currently extracting features in "car_horn" from 26176-1-0-0.wav (# 106)
# 	Splitting "26176-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 26177-1-0-0.wav (# 107)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 26177-1-1-0.wav (# 107)
# 	Splitting "26177-1-1-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 26177-1-2-0.wav (# 108)
# 	Splitting "26177-1-2-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 26185-1-0-0.wav (# 109)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 26185-1-1-0.wav (# 109)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 26186-1-0-0.wav (# 109)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 27068-1-0-0.wav (# 109)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 28808-1-0-0.wav (# 109)
# 	Splitting "28808-1-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 28808-1-0-1.wav (# 110)
# 	Splitting "28808-1-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 28808-1-0-10.wav (# 111)
# 	Splitting "28808-1-0-10.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 28808-1-0-11.wav (# 112)
# 	Splitting "28808-1-0-11.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 28808-1-0-2.wav (# 113)
# 	Splitting "28808-1-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 28808-1-0-3.wav (# 114)
# 	Splitting "28808-1-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 28808-1-0-4.wav (# 115)
# 	Splitting "28808-1-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 28808-1-0-5.wav (# 116)
# 	Splitting "28808-1-0-5.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 28808-1-0-6.wav (# 117)
# 	Splitting "28808-1-0-6.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 28808-1-0-7.wav (# 118)
# 	Splitting "28808-1-0-7.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 28808-1-0-8.wav (# 119)
# 	Splitting "28808-1-0-8.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 28808-1-0-9.wav (# 120)
# 	Splitting "28808-1-0-9.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 28808-1-1-0.wav (# 121)
# 	Splitting "28808-1-1-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 28808-1-1-1.wav (# 122)
# 	Splitting "28808-1-1-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 2937-1-0-0.wav (# 123)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 29932-1-0-0.wav (# 123)
# 	Splitting "29932-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 29932-1-1-0.wav (# 124)
# 	Splitting "29932-1-1-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 32417-1-0-0.wav (# 125)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 34241-1-0-0.wav (# 125)
# 	Splitting "34241-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 34241-1-1-0.wav (# 126)
# 	Splitting "34241-1-1-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 34241-1-2-0.wav (# 127)
# 	Splitting "34241-1-2-0.wav" into 3 1-second part(s)
# Currently extracting features in "car_horn" from 42101-1-1-0.wav (# 128)
# 	Splitting "42101-1-1-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 43802-1-0-0.wav (# 129)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 43802-1-1-0.wav (# 129)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 43802-1-2-0.wav (# 129)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 43803-1-0-0.wav (# 129)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 44278-1-0-0.wav (# 129)
# 	Splitting "44278-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 44278-1-1-0.wav (# 130)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 45256-1-0-0.wav (# 130)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 46391-1-0-0.wav (# 130)
# 	Splitting "46391-1-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 46391-1-1-0.wav (# 131)
# 	Splitting "46391-1-1-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 49974-1-0-0.wav (# 132)
# 	Splitting "49974-1-0-0.wav" into 2 1-second part(s)
# Currently extracting features in "car_horn" from 52102-1-0-0.wav (# 133)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 54086-1-0-0.wav (# 133)
# 	Splitting "54086-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 54086-1-1-0.wav (# 134)
# 	Splitting "54086-1-1-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 54086-1-2-0.wav (# 135)
# 	Splitting "54086-1-2-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 54187-1-0-0.wav (# 136)
# 	Splitting "54187-1-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 54187-1-0-1.wav (# 137)
# 	Splitting "54187-1-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 54187-1-0-2.wav (# 138)
# 	Splitting "54187-1-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 54187-1-0-3.wav (# 139)
# 	Splitting "54187-1-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 54187-1-0-4.wav (# 140)
# 	Splitting "54187-1-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 57607-1-0-0.wav (# 141)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 58202-1-0-0.wav (# 141)
# 	Splitting "58202-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 65472-1-0-0.wav (# 142)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 66115-1-0-0.wav (# 142)
# 	Splitting "66115-1-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 66115-1-0-1.wav (# 143)
# 	Splitting "66115-1-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 68657-1-0-0.wav (# 144)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 6984-1-0-0.wav (# 144)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 71309-1-0-0.wav (# 144)
# 	Splitting "71309-1-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 71309-1-0-1.wav (# 145)
# 	Splitting "71309-1-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 71309-1-0-2.wav (# 146)
# 	Splitting "71309-1-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 71309-1-0-3.wav (# 147)
# 	Splitting "71309-1-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 71309-1-0-4.wav (# 148)
# 	Splitting "71309-1-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 71309-1-0-5.wav (# 149)
# 	Splitting "71309-1-0-5.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 71309-1-0-6.wav (# 150)
# 	Splitting "71309-1-0-6.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 71309-1-0-7.wav (# 151)
# 	Splitting "71309-1-0-7.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 71309-1-0-8.wav (# 152)
# 	Splitting "71309-1-0-8.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 71309-1-1-0.wav (# 153)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 71309-1-2-0.wav (# 153)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 71439-1-0-0.wav (# 153)
# 	Splitting "71439-1-0-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 71439-1-1-0.wav (# 154)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 71439-1-2-0.wav (# 154)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 71439-1-3-0.wav (# 154)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 72259-1-0-0.wav (# 154)
# 	Splitting "72259-1-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-0-1.wav (# 155)
# 	Splitting "72259-1-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-0-2.wav (# 156)
# 	Splitting "72259-1-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-0-3.wav (# 157)
# 	Splitting "72259-1-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-0-4.wav (# 158)
# 	Splitting "72259-1-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-0-5.wav (# 159)
# 	Splitting "72259-1-0-5.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-1-0.wav (# 160)
# 	Splitting "72259-1-1-0.wav" into 3 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-10-0.wav (# 161)
# 	Splitting "72259-1-10-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-10-1.wav (# 162)
# 	Splitting "72259-1-10-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-10-10.wav (# 163)
# 	Splitting "72259-1-10-10.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-10-11.wav (# 164)
# 	Splitting "72259-1-10-11.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-10-12.wav (# 165)
# 	Splitting "72259-1-10-12.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-10-13.wav (# 166)
# 	Splitting "72259-1-10-13.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-10-14.wav (# 167)
# 	Splitting "72259-1-10-14.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-10-2.wav (# 168)
# 	Splitting "72259-1-10-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-10-3.wav (# 169)
# 	Splitting "72259-1-10-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-10-4.wav (# 170)
# 	Splitting "72259-1-10-4.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-10-5.wav (# 171)
# 	Splitting "72259-1-10-5.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-10-6.wav (# 172)
# 	Splitting "72259-1-10-6.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-10-7.wav (# 173)
# 	Splitting "72259-1-10-7.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-10-8.wav (# 174)
# 	Splitting "72259-1-10-8.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-10-9.wav (# 175)
# 	Splitting "72259-1-10-9.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-2-0.wav (# 176)
# 	Splitting "72259-1-2-0.wav" into 3 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-3-0.wav (# 177)
# 	Splitting "72259-1-3-0.wav" into 3 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-5-0.wav (# 178)
# 	Splitting "72259-1-5-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-5-1.wav (# 179)
# 	Splitting "72259-1-5-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-5-2.wav (# 180)
# 	Splitting "72259-1-5-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-5-3.wav (# 181)
# 	Splitting "72259-1-5-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-5-4.wav (# 182)
# 	Splitting "72259-1-5-4.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-6-0.wav (# 183)
# 	Splitting "72259-1-6-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-6-1.wav (# 184)
# 	Splitting "72259-1-6-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-0.wav (# 185)
# 	Splitting "72259-1-7-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-1.wav (# 186)
# 	Splitting "72259-1-7-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-10.wav (# 187)
# 	Splitting "72259-1-7-10.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-11.wav (# 188)
# 	Splitting "72259-1-7-11.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-12.wav (# 189)
# 	Splitting "72259-1-7-12.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-13.wav (# 190)
# 	Splitting "72259-1-7-13.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-14.wav (# 191)
# 	Splitting "72259-1-7-14.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-15.wav (# 192)
# 	Splitting "72259-1-7-15.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-16.wav (# 193)
# 	Splitting "72259-1-7-16.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-17.wav (# 194)
# 	Splitting "72259-1-7-17.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-18.wav (# 195)
# 	Splitting "72259-1-7-18.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-19.wav (# 196)
# 	Splitting "72259-1-7-19.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-2.wav (# 197)
# 	Splitting "72259-1-7-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-20.wav (# 198)
# 	Splitting "72259-1-7-20.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-21.wav (# 199)
# 	Splitting "72259-1-7-21.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-22.wav (# 200)
# 	Splitting "72259-1-7-22.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-3.wav (# 201)
# 	Splitting "72259-1-7-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-4.wav (# 202)
# 	Splitting "72259-1-7-4.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-5.wav (# 203)
# 	Splitting "72259-1-7-5.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-6.wav (# 204)
# 	Splitting "72259-1-7-6.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-7.wav (# 205)
# 	Splitting "72259-1-7-7.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-8.wav (# 206)
# 	Splitting "72259-1-7-8.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-7-9.wav (# 207)
# 	Splitting "72259-1-7-9.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-8-0.wav (# 208)
# 	Splitting "72259-1-8-0.wav" into 3 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-9-0.wav (# 209)
# 	Splitting "72259-1-9-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-9-1.wav (# 210)
# 	Splitting "72259-1-9-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-9-10.wav (# 211)
# 	Splitting "72259-1-9-10.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-9-11.wav (# 212)
# 	Splitting "72259-1-9-11.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-9-12.wav (# 213)
# 	Splitting "72259-1-9-12.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-9-13.wav (# 214)
# 	Splitting "72259-1-9-13.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-9-14.wav (# 215)
# 	Splitting "72259-1-9-14.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-9-15.wav (# 216)
# 	Splitting "72259-1-9-15.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-9-16.wav (# 217)
# 	Splitting "72259-1-9-16.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-9-17.wav (# 218)
# 	Splitting "72259-1-9-17.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-9-2.wav (# 219)
# 	Splitting "72259-1-9-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-9-3.wav (# 220)
# 	Splitting "72259-1-9-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-9-4.wav (# 221)
# 	Splitting "72259-1-9-4.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-9-5.wav (# 222)
# 	Splitting "72259-1-9-5.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-9-6.wav (# 223)
# 	Splitting "72259-1-9-6.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-9-7.wav (# 224)
# 	Splitting "72259-1-9-7.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-9-8.wav (# 225)
# 	Splitting "72259-1-9-8.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72259-1-9-9.wav (# 226)
# 	Splitting "72259-1-9-9.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72567-1-0-0.wav (# 227)
# 	Splitting "72567-1-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72567-1-0-1.wav (# 228)
# 	Splitting "72567-1-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72567-1-1-0.wav (# 229)
# 	Splitting "72567-1-1-0.wav" into 3 1-second part(s)
# Currently extracting features in "car_horn" from 72567-1-2-0.wav (# 230)
# 	Splitting "72567-1-2-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72567-1-2-1.wav (# 231)
# 	Splitting "72567-1-2-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72567-1-2-2.wav (# 232)
# 	Splitting "72567-1-2-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72567-1-2-3.wav (# 233)
# 	Splitting "72567-1-2-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72567-1-2-4.wav (# 234)
# 	Splitting "72567-1-2-4.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72567-1-2-5.wav (# 235)
# 	Splitting "72567-1-2-5.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72567-1-3-0.wav (# 236)
# 	Splitting "72567-1-3-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 72567-1-4-0.wav (# 237)
# 	Splitting "72567-1-4-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72567-1-4-1.wav (# 238)
# 	Splitting "72567-1-4-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72567-1-4-2.wav (# 239)
# 	Splitting "72567-1-4-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72567-1-4-3.wav (# 240)
# 	Splitting "72567-1-4-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72567-1-4-4.wav (# 241)
# 	Splitting "72567-1-4-4.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72567-1-4-5.wav (# 242)
# 	Splitting "72567-1-4-5.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72567-1-4-6.wav (# 243)
# 	Splitting "72567-1-4-6.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72567-1-4-7.wav (# 244)
# 	Splitting "72567-1-4-7.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 72567-1-5-0.wav (# 245)
# 	Splitting "72567-1-5-0.wav" into 3 1-second part(s)
# Currently extracting features in "car_horn" from 73168-1-0-0.wav (# 246)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 73168-1-1-0.wav (# 246)
# 	Splitting "73168-1-1-0.wav" into 1 1-second part(s)
# Currently extracting features in "car_horn" from 73168-1-2-0.wav (# 247)
# *ignored, file under 1 second long*
# Currently extracting features in "car_horn" from 7389-1-0-0.wav (# 247)
# 	Splitting "7389-1-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-0-1.wav (# 248)
# 	Splitting "7389-1-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-0-2.wav (# 249)
# 	Splitting "7389-1-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-0-3.wav (# 250)
# 	Splitting "7389-1-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-0-4.wav (# 251)
# 	Splitting "7389-1-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-0-5.wav (# 252)
# 	Splitting "7389-1-0-5.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-0-6.wav (# 253)
# 	Splitting "7389-1-0-6.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-0-7.wav (# 254)
# 	Splitting "7389-1-0-7.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-1-0.wav (# 255)
# 	Splitting "7389-1-1-0.wav" into 3 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-2-0.wav (# 256)
# 	Splitting "7389-1-2-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-2-1.wav (# 257)
# 	Splitting "7389-1-2-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-2-2.wav (# 258)
# 	Splitting "7389-1-2-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-2-3.wav (# 259)
# 	Splitting "7389-1-2-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-3-0.wav (# 260)
# 	Splitting "7389-1-3-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-3-1.wav (# 261)
# 	Splitting "7389-1-3-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-3-2.wav (# 262)
# 	Splitting "7389-1-3-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-3-3.wav (# 263)
# 	Splitting "7389-1-3-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-3-4.wav (# 264)
# 	Splitting "7389-1-3-4.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-3-5.wav (# 265)
# 	Splitting "7389-1-3-5.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-4-0.wav (# 266)
# 	Splitting "7389-1-4-0.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-4-1.wav (# 267)
# 	Splitting "7389-1-4-1.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-4-10.wav (# 268)
# 	Splitting "7389-1-4-10.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-4-11.wav (# 269)
# 	Splitting "7389-1-4-11.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-4-12.wav (# 270)
# 	Splitting "7389-1-4-12.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-4-13.wav (# 271)
# 	Splitting "7389-1-4-13.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-4-14.wav (# 272)
# 	Splitting "7389-1-4-14.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-4-15.wav (# 273)
# 	Splitting "7389-1-4-15.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-4-2.wav (# 274)
# 	Splitting "7389-1-4-2.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-4-3.wav (# 275)
# 	Splitting "7389-1-4-3.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-4-4.wav (# 276)
# 	Splitting "7389-1-4-4.wav" into 4 1-second part(s)
# Currently extracting features in "car_horn" from 7389-1-4-5.wav (# 277)
# 	Splitting "7389-1-4-5.wav" into 4 1-second part(s)
# ...
# 	Splitting "83196-9-0-10.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 83196-9-0-13.wav (# 881)
# 	Splitting "83196-9-0-13.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 83196-9-0-14.wav (# 882)
# 	Splitting "83196-9-0-14.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 83196-9-0-15.wav (# 883)
# 	Splitting "83196-9-0-15.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 83196-9-0-3.wav (# 884)
# 	Splitting "83196-9-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 83196-9-0-9.wav (# 885)
# 	Splitting "83196-9-0-9.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 83199-9-0-0.wav (# 886)
# 	Splitting "83199-9-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 84249-9-0-10.wav (# 887)
# 	Splitting "84249-9-0-10.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 84249-9-0-11.wav (# 888)
# 	Splitting "84249-9-0-11.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 84249-9-0-3.wav (# 889)
# 	Splitting "84249-9-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 84249-9-0-6.wav (# 890)
# 	Splitting "84249-9-0-6.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 84249-9-0-7.wav (# 891)
# 	Splitting "84249-9-0-7.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 84249-9-0-8.wav (# 892)
# 	Splitting "84249-9-0-8.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 89442-9-0-14.wav (# 893)
# 	Splitting "89442-9-0-14.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 89442-9-0-17.wav (# 894)
# 	Splitting "89442-9-0-17.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 89442-9-0-34.wav (# 895)
# 	Splitting "89442-9-0-34.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 89442-9-0-5.wav (# 896)
# 	Splitting "89442-9-0-5.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 89442-9-0-6.wav (# 897)
# 	Splitting "89442-9-0-6.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 89442-9-0-7.wav (# 898)
# 	Splitting "89442-9-0-7.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 89443-9-0-1.wav (# 899)
# 	Splitting "89443-9-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 89443-9-0-16.wav (# 900)
# 	Splitting "89443-9-0-16.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 89443-9-0-17.wav (# 901)
# 	Splitting "89443-9-0-17.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 89443-9-0-2.wav (# 902)
# 	Splitting "89443-9-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 89443-9-0-48.wav (# 903)
# 	Splitting "89443-9-0-48.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 89443-9-0-50.wav (# 904)
# 	Splitting "89443-9-0-50.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 93065-9-0-12.wav (# 905)
# 	Splitting "93065-9-0-12.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 93065-9-0-14.wav (# 906)
# 	Splitting "93065-9-0-14.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 93065-9-0-17.wav (# 907)
# 	Splitting "93065-9-0-17.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 93065-9-0-2.wav (# 908)
# 	Splitting "93065-9-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 93065-9-0-4.wav (# 909)
# 	Splitting "93065-9-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 93065-9-0-7.wav (# 910)
# 	Splitting "93065-9-0-7.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 93193-9-0-4.wav (# 911)
# 	Splitting "93193-9-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 93193-9-1-11.wav (# 912)
# 	Splitting "93193-9-1-11.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 93193-9-1-18.wav (# 913)
# 	Splitting "93193-9-1-18.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 93193-9-1-19.wav (# 914)
# 	Splitting "93193-9-1-19.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 93193-9-1-22.wav (# 915)
# 	Splitting "93193-9-1-22.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 93193-9-1-6.wav (# 916)
# 	Splitting "93193-9-1-6.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 94182-9-0-0.wav (# 917)
# 	Splitting "94182-9-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 94182-9-0-10.wav (# 918)
# 	Splitting "94182-9-0-10.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 94182-9-0-16.wav (# 919)
# 	Splitting "94182-9-0-16.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 94182-9-0-20.wav (# 920)
# 	Splitting "94182-9-0-20.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 94182-9-0-23.wav (# 921)
# 	Splitting "94182-9-0-23.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 94182-9-0-25.wav (# 922)
# 	Splitting "94182-9-0-25.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 94182-9-0-9.wav (# 923)
# 	Splitting "94182-9-0-9.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 94631-9-0-12.wav (# 924)
# 	Splitting "94631-9-0-12.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 94631-9-0-16.wav (# 925)
# 	Splitting "94631-9-0-16.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 94631-9-1-16.wav (# 926)
# 	Splitting "94631-9-1-16.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 94631-9-1-2.wav (# 927)
# 	Splitting "94631-9-1-2.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 94631-9-1-25.wav (# 928)
# 	Splitting "94631-9-1-25.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 94631-9-1-3.wav (# 929)
# 	Splitting "94631-9-1-3.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96169-9-1-10.wav (# 930)
# 	Splitting "96169-9-1-10.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96169-9-1-3.wav (# 931)
# 	Splitting "96169-9-1-3.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96169-9-1-49.wav (# 932)
# 	Splitting "96169-9-1-49.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96169-9-1-55.wav (# 933)
# 	Splitting "96169-9-1-55.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96169-9-1-61.wav (# 934)
# 	Splitting "96169-9-1-61.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96169-9-1-74.wav (# 935)
# 	Splitting "96169-9-1-74.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96475-9-0-0.wav (# 936)
# 	Splitting "96475-9-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96475-9-0-3.wav (# 937)
# 	Splitting "96475-9-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96475-9-0-4.wav (# 938)
# 	Splitting "96475-9-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96475-9-0-5.wav (# 939)
# 	Splitting "96475-9-0-5.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96475-9-0-6.wav (# 940)
# 	Splitting "96475-9-0-6.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96475-9-0-9.wav (# 941)
# 	Splitting "96475-9-0-9.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96920-9-0-0.wav (# 942)
# 	Splitting "96920-9-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96920-9-0-11.wav (# 943)
# 	Splitting "96920-9-0-11.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96920-9-0-13.wav (# 944)
# 	Splitting "96920-9-0-13.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96920-9-0-2.wav (# 945)
# 	Splitting "96920-9-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96920-9-0-3.wav (# 946)
# 	Splitting "96920-9-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96920-9-0-8.wav (# 947)
# 	Splitting "96920-9-0-8.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96921-9-0-1.wav (# 948)
# 	Splitting "96921-9-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96921-9-0-11.wav (# 949)
# 	Splitting "96921-9-0-11.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96921-9-0-17.wav (# 950)
# 	Splitting "96921-9-0-17.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96921-9-0-18.wav (# 951)
# 	Splitting "96921-9-0-18.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96921-9-0-4.wav (# 952)
# 	Splitting "96921-9-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 96921-9-0-9.wav (# 953)
# 	Splitting "96921-9-0-9.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98202-9-0-10.wav (# 954)
# 	Splitting "98202-9-0-10.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98202-9-0-4.wav (# 955)
# 	Splitting "98202-9-0-4.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98202-9-0-7.wav (# 956)
# 	Splitting "98202-9-0-7.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98202-9-1-20.wav (# 957)
# 	Splitting "98202-9-1-20.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98202-9-1-27.wav (# 958)
# 	Splitting "98202-9-1-27.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98202-9-1-5.wav (# 959)
# 	Splitting "98202-9-1-5.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98263-9-0-1.wav (# 960)
# 	Splitting "98263-9-0-1.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98263-9-0-10.wav (# 961)
# 	Splitting "98263-9-0-10.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98263-9-0-22.wav (# 962)
# 	Splitting "98263-9-0-22.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98263-9-0-24.wav (# 963)
# 	Splitting "98263-9-0-24.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98263-9-0-33.wav (# 964)
# 	Splitting "98263-9-0-33.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98263-9-0-35.wav (# 965)
# 	Splitting "98263-9-0-35.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98680-9-0-11.wav (# 966)
# 	Splitting "98680-9-0-11.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98680-9-0-14.wav (# 967)
# 	Splitting "98680-9-0-14.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98680-9-0-2.wav (# 968)
# 	Splitting "98680-9-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98680-9-0-3.wav (# 969)
# 	Splitting "98680-9-0-3.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98680-9-0-5.wav (# 970)
# 	Splitting "98680-9-0-5.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98681-9-0-0.wav (# 971)
# 	Splitting "98681-9-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98681-9-0-11.wav (# 972)
# 	Splitting "98681-9-0-11.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98681-9-0-12.wav (# 973)
# 	Splitting "98681-9-0-12.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98681-9-0-5.wav (# 974)
# 	Splitting "98681-9-0-5.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98681-9-0-6.wav (# 975)
# 	Splitting "98681-9-0-6.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 98681-9-0-7.wav (# 976)
# 	Splitting "98681-9-0-7.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99157-9-0-10.wav (# 977)
# 	Splitting "99157-9-0-10.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99157-9-0-15.wav (# 978)
# 	Splitting "99157-9-0-15.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99157-9-0-16.wav (# 979)
# 	Splitting "99157-9-0-16.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99157-9-0-22.wav (# 980)
# 	Splitting "99157-9-0-22.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99157-9-0-24.wav (# 981)
# 	Splitting "99157-9-0-24.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99157-9-0-31.wav (# 982)
# 	Splitting "99157-9-0-31.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99179-9-0-12.wav (# 983)
# 	Splitting "99179-9-0-12.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99179-9-0-17.wav (# 984)
# 	Splitting "99179-9-0-17.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99179-9-0-19.wav (# 985)
# 	Splitting "99179-9-0-19.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99179-9-0-38.wav (# 986)
# 	Splitting "99179-9-0-38.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99179-9-0-53.wav (# 987)
# 	Splitting "99179-9-0-53.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99179-9-0-58.wav (# 988)
# 	Splitting "99179-9-0-58.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99180-9-0-0.wav (# 989)
# 	Splitting "99180-9-0-0.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99180-9-0-2.wav (# 990)
# 	Splitting "99180-9-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99180-9-0-36.wav (# 991)
# 	Splitting "99180-9-0-36.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99180-9-0-48.wav (# 992)
# 	Splitting "99180-9-0-48.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99180-9-0-49.wav (# 993)
# 	Splitting "99180-9-0-49.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99180-9-0-7.wav (# 994)
# 	Splitting "99180-9-0-7.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99710-9-0-11.wav (# 995)
# 	Splitting "99710-9-0-11.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99710-9-0-12.wav (# 996)
# 	Splitting "99710-9-0-12.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99710-9-0-16.wav (# 997)
# 	Splitting "99710-9-0-16.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99710-9-0-2.wav (# 998)
# 	Splitting "99710-9-0-2.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99710-9-0-5.wav (# 999)
# 	Splitting "99710-9-0-5.wav" into 4 1-second part(s)
# Currently extracting features in "street_music" from 99710-9-0-6.wav (# 1000)
# 	Splitting "99710-9-0-6.wav" into 4 1-second part(s)
# ----- done. -----
# Total file count: 6086
# Files ignored: 350
# Extracted 22770 windows from 5736 Files
# Shape of dataframe: (22770, 48, 21)

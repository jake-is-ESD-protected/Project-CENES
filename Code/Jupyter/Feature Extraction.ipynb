# %% [markdown]
# # Feature Extraction
#
# Since the filters have been explored, the data displayed in spectrograms can now be written to `csv`-files for later training of the NN. The amount of data per soundfile is calculated with the following formula:
#
# ```
# size_in_b = n_frames * n_bands * sizeof(float32)
# ```
#
# This is one of the major strenghts of this method: instead of storing `512` bins `1024` times per second, the octave bank only creates `31` bins `24` times a second.

# %%
import os
from octafilt3r import filter as o3f
from octafilt3r import weightings as o3w
import librosa as lr
import numpy as np
import pipeline.config as conf

# %%
param_dict = conf.open_params()

# %%
files_ignored = 0
tot_cnt = 0

df = []
labels = []
leq = []
for class_ in os.listdir(param_dict["source_dir"]):
    cnt = 1
    for filename in os.listdir(f'{param_dict["source_dir"]}{class_}'):

        print(f'Currently extracting features in "{class_}" from {filename} (# {cnt})')

        wav = f'{param_dict["source_dir"]}{class_}/{filename}'
        y, sr = lr.load(wav, sr=param_dict["fs"], mono=True, duration=param_dict["max_dur"])

        y = o3w.A_weight(y, sr)

        wins = int(len(y)/param_dict["window_size"])
        if wins == 0:
            files_ignored += 1
            print('*ignored, file under 1 second long*')
            continue    # skip files which are shorter than 1s

        # obtain features of whole file
        feats, fcs, lq = o3f.rolling_oct_bank(y, 
                                        param_dict["fs"], 
                                        ratio=param_dict["oct_bw_ratio"], 
                                        fmax=param_dict["fmax"], 
                                        fmin=param_dict["fmin"], 
                                        frame_size=param_dict["frame_size"], 
                                        n_decimations=param_dict["dec_stages"])

        # flip array to match embedded system arrays
        feats = feats[:, ::-1]

        print(f'\tSplitting "{filename}" into {wins} 1-second part(s)')
        for win in range(wins):    # ignore parts of file which is not in a full window
            cur_feats = feats[param_dict["fps"] * win:param_dict["fps"] * (win + 1)]
            df.append(cur_feats)
            labels.append(class_)
            leq.append(lq[win])
        cnt += 1

    tot_cnt += cnt


df = np.dstack(df)
df = np.transpose(df, (2, 0, 1))

df_2d = df.reshape(df.shape[0], -1)
np.savetxt(param_dict["extr_txt_fp"], df_2d)
with open(param_dict["label_txt_fp"], "w") as f:
    for i in labels:
        f.writelines(i + '\n')
with open(param_dict["leq_txt_fp"], "w") as f:
    for i in leq:
        f.writelines(str(i) + '\n')        


print(f'----- done. -----\nTotal file count: {tot_cnt}\nFiles ignored: {files_ignored}\nExtracted {len(df)} windows from {tot_cnt-files_ignored} Files')
print(f'Shape of dataframe: {df.shape}')
print(f'Shape of labels: {np.shape(labels)}')
print(f'Shape of LEQs: {np.shape(leq)}')
# Out:
# Currently extracting features in "airplane" from 1-11687-A-47.wav (# 1)
# 	Splitting "1-11687-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 1-24796-A-47.wav (# 2)
# 	Splitting "1-24796-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 1-36929-A-47.wav (# 3)
# 	Splitting "1-36929-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 1-43807-A-47.wav (# 4)
# 	Splitting "1-43807-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 1-43807-B-47.wav (# 5)
# 	Splitting "1-43807-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 1-43807-C-47.wav (# 6)
# 	Splitting "1-43807-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 1-43807-D-47.wav (# 7)
# 	Splitting "1-43807-D-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 1-53467-A-47.wav (# 8)
# 	Splitting "1-53467-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 2-105270-A-47.wav (# 9)
# 	Splitting "2-105270-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 2-106849-A-47.wav (# 10)
# 	Splitting "2-106849-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 2-160888-A-47.wav (# 11)
# 	Splitting "2-160888-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 2-74361-A-47.wav (# 12)
# 	Splitting "2-74361-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 2-78781-A-47.wav (# 13)
# 	Splitting "2-78781-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 2-78799-A-47.wav (# 14)
# 	Splitting "2-78799-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 2-96654-A-47.wav (# 15)
# 	Splitting "2-96654-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 2-98866-A-47.wav (# 16)
# 	Splitting "2-98866-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 3-115387-A-47.wav (# 17)
# 	Splitting "3-115387-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 3-115387-B-47.wav (# 18)
# 	Splitting "3-115387-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 3-115387-C-47.wav (# 19)
# 	Splitting "3-115387-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 3-128512-A-47.wav (# 20)
# 	Splitting "3-128512-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 3-128512-B-47.wav (# 21)
# 	Splitting "3-128512-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 3-143560-A-47.wav (# 22)
# 	Splitting "3-143560-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 3-143562-A-47.wav (# 23)
# 	Splitting "3-143562-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 3-193767-A-47.wav (# 24)
# 	Splitting "3-193767-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 4-161099-A-47.wav (# 25)
# 	Splitting "4-161099-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 4-161099-B-47.wav (# 26)
# 	Splitting "4-161099-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 4-161100-A-47.wav (# 27)
# 	Splitting "4-161100-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 4-161103-A-47.wav (# 28)
# 	Splitting "4-161103-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 4-161105-A-47.wav (# 29)
# 	Splitting "4-161105-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 4-161105-B-47.wav (# 30)
# 	Splitting "4-161105-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 4-251959-A-47.wav (# 31)
# 	Splitting "4-251959-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 4-255371-A-47.wav (# 32)
# 	Splitting "4-255371-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 5-215445-A-47.wav (# 33)
# 	Splitting "5-215445-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 5-215447-A-47.wav (# 34)
# 	Splitting "5-215447-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 5-215449-A-47.wav (# 35)
# 	Splitting "5-215449-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 5-235956-A-47.wav (# 36)
# 	Splitting "5-235956-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 5-251957-A-47.wav (# 37)
# 	Splitting "5-251957-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 5-251962-A-47.wav (# 38)
# 	Splitting "5-251962-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 5-251963-A-47.wav (# 39)
# 	Splitting "5-251963-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from 5-251971-A-47.wav (# 40)
# 	Splitting "5-251971-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_1-11687-A-47.wav (# 41)
# 	Splitting "n_1-11687-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_1-24796-A-47.wav (# 42)
# 	Splitting "n_1-24796-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_1-36929-A-47.wav (# 43)
# 	Splitting "n_1-36929-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_1-43807-A-47.wav (# 44)
# 	Splitting "n_1-43807-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_1-43807-B-47.wav (# 45)
# 	Splitting "n_1-43807-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_1-43807-C-47.wav (# 46)
# 	Splitting "n_1-43807-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_1-43807-D-47.wav (# 47)
# 	Splitting "n_1-43807-D-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_1-53467-A-47.wav (# 48)
# 	Splitting "n_1-53467-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_2-105270-A-47.wav (# 49)
# 	Splitting "n_2-105270-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_2-106849-A-47.wav (# 50)
# 	Splitting "n_2-106849-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_2-160888-A-47.wav (# 51)
# 	Splitting "n_2-160888-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_2-74361-A-47.wav (# 52)
# 	Splitting "n_2-74361-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_2-78781-A-47.wav (# 53)
# 	Splitting "n_2-78781-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_2-78799-A-47.wav (# 54)
# 	Splitting "n_2-78799-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_2-96654-A-47.wav (# 55)
# 	Splitting "n_2-96654-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_2-98866-A-47.wav (# 56)
# 	Splitting "n_2-98866-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_3-115387-A-47.wav (# 57)
# 	Splitting "n_3-115387-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_3-115387-B-47.wav (# 58)
# 	Splitting "n_3-115387-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_3-115387-C-47.wav (# 59)
# 	Splitting "n_3-115387-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_3-128512-A-47.wav (# 60)
# 	Splitting "n_3-128512-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_3-128512-B-47.wav (# 61)
# 	Splitting "n_3-128512-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_3-143560-A-47.wav (# 62)
# 	Splitting "n_3-143560-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_3-143562-A-47.wav (# 63)
# 	Splitting "n_3-143562-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_3-193767-A-47.wav (# 64)
# 	Splitting "n_3-193767-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_4-161099-A-47.wav (# 65)
# 	Splitting "n_4-161099-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_4-161099-B-47.wav (# 66)
# 	Splitting "n_4-161099-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_4-161100-A-47.wav (# 67)
# 	Splitting "n_4-161100-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_4-161103-A-47.wav (# 68)
# 	Splitting "n_4-161103-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_4-161105-A-47.wav (# 69)
# 	Splitting "n_4-161105-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_4-161105-B-47.wav (# 70)
# 	Splitting "n_4-161105-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_4-251959-A-47.wav (# 71)
# 	Splitting "n_4-251959-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_4-255371-A-47.wav (# 72)
# 	Splitting "n_4-255371-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_5-215445-A-47.wav (# 73)
# 	Splitting "n_5-215445-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_5-215447-A-47.wav (# 74)
# 	Splitting "n_5-215447-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_5-215449-A-47.wav (# 75)
# 	Splitting "n_5-215449-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_5-235956-A-47.wav (# 76)
# 	Splitting "n_5-235956-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_5-251957-A-47.wav (# 77)
# 	Splitting "n_5-251957-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_5-251962-A-47.wav (# 78)
# 	Splitting "n_5-251962-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_5-251963-A-47.wav (# 79)
# 	Splitting "n_5-251963-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from n_5-251971-A-47.wav (# 80)
# 	Splitting "n_5-251971-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from offs025_1-11687-A-47.wav (# 81)
# 	Splitting "offs025_1-11687-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_1-24796-A-47.wav (# 82)
# 	Splitting "offs025_1-24796-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_1-36929-A-47.wav (# 83)
# 	Splitting "offs025_1-36929-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_1-43807-A-47.wav (# 84)
# 	Splitting "offs025_1-43807-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_1-43807-B-47.wav (# 85)
# 	Splitting "offs025_1-43807-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_1-43807-C-47.wav (# 86)
# 	Splitting "offs025_1-43807-C-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_1-43807-D-47.wav (# 87)
# 	Splitting "offs025_1-43807-D-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_1-53467-A-47.wav (# 88)
# 	Splitting "offs025_1-53467-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_2-105270-A-47.wav (# 89)
# 	Splitting "offs025_2-105270-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_2-106849-A-47.wav (# 90)
# 	Splitting "offs025_2-106849-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_2-160888-A-47.wav (# 91)
# 	Splitting "offs025_2-160888-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_2-74361-A-47.wav (# 92)
# 	Splitting "offs025_2-74361-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_2-78781-A-47.wav (# 93)
# 	Splitting "offs025_2-78781-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_2-78799-A-47.wav (# 94)
# 	Splitting "offs025_2-78799-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_2-96654-A-47.wav (# 95)
# 	Splitting "offs025_2-96654-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_2-98866-A-47.wav (# 96)
# 	Splitting "offs025_2-98866-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_3-115387-A-47.wav (# 97)
# 	Splitting "offs025_3-115387-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_3-115387-B-47.wav (# 98)
# 	Splitting "offs025_3-115387-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_3-115387-C-47.wav (# 99)
# 	Splitting "offs025_3-115387-C-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_3-128512-A-47.wav (# 100)
# 	Splitting "offs025_3-128512-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_3-128512-B-47.wav (# 101)
# 	Splitting "offs025_3-128512-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_3-143560-A-47.wav (# 102)
# 	Splitting "offs025_3-143560-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_3-143562-A-47.wav (# 103)
# 	Splitting "offs025_3-143562-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_3-193767-A-47.wav (# 104)
# 	Splitting "offs025_3-193767-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_4-161099-A-47.wav (# 105)
# 	Splitting "offs025_4-161099-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_4-161099-B-47.wav (# 106)
# 	Splitting "offs025_4-161099-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_4-161100-A-47.wav (# 107)
# 	Splitting "offs025_4-161100-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_4-161103-A-47.wav (# 108)
# 	Splitting "offs025_4-161103-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_4-161105-A-47.wav (# 109)
# 	Splitting "offs025_4-161105-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_4-161105-B-47.wav (# 110)
# 	Splitting "offs025_4-161105-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_4-251959-A-47.wav (# 111)
# 	Splitting "offs025_4-251959-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_4-255371-A-47.wav (# 112)
# 	Splitting "offs025_4-255371-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_5-215445-A-47.wav (# 113)
# 	Splitting "offs025_5-215445-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_5-215447-A-47.wav (# 114)
# 	Splitting "offs025_5-215447-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_5-215449-A-47.wav (# 115)
# 	Splitting "offs025_5-215449-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_5-235956-A-47.wav (# 116)
# 	Splitting "offs025_5-235956-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_5-251957-A-47.wav (# 117)
# 	Splitting "offs025_5-251957-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_5-251962-A-47.wav (# 118)
# 	Splitting "offs025_5-251962-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_5-251963-A-47.wav (# 119)
# 	Splitting "offs025_5-251963-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs025_5-251971-A-47.wav (# 120)
# 	Splitting "offs025_5-251971-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_1-11687-A-47.wav (# 121)
# 	Splitting "offs05_1-11687-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_1-24796-A-47.wav (# 122)
# 	Splitting "offs05_1-24796-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_1-36929-A-47.wav (# 123)
# 	Splitting "offs05_1-36929-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_1-43807-A-47.wav (# 124)
# 	Splitting "offs05_1-43807-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_1-43807-B-47.wav (# 125)
# 	Splitting "offs05_1-43807-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_1-43807-C-47.wav (# 126)
# 	Splitting "offs05_1-43807-C-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_1-43807-D-47.wav (# 127)
# 	Splitting "offs05_1-43807-D-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_1-53467-A-47.wav (# 128)
# 	Splitting "offs05_1-53467-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_2-105270-A-47.wav (# 129)
# 	Splitting "offs05_2-105270-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_2-106849-A-47.wav (# 130)
# 	Splitting "offs05_2-106849-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_2-160888-A-47.wav (# 131)
# 	Splitting "offs05_2-160888-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_2-74361-A-47.wav (# 132)
# 	Splitting "offs05_2-74361-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_2-78781-A-47.wav (# 133)
# 	Splitting "offs05_2-78781-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_2-78799-A-47.wav (# 134)
# 	Splitting "offs05_2-78799-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_2-96654-A-47.wav (# 135)
# 	Splitting "offs05_2-96654-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_2-98866-A-47.wav (# 136)
# 	Splitting "offs05_2-98866-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_3-115387-A-47.wav (# 137)
# 	Splitting "offs05_3-115387-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_3-115387-B-47.wav (# 138)
# 	Splitting "offs05_3-115387-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_3-115387-C-47.wav (# 139)
# 	Splitting "offs05_3-115387-C-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_3-128512-A-47.wav (# 140)
# 	Splitting "offs05_3-128512-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_3-128512-B-47.wav (# 141)
# 	Splitting "offs05_3-128512-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_3-143560-A-47.wav (# 142)
# 	Splitting "offs05_3-143560-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_3-143562-A-47.wav (# 143)
# 	Splitting "offs05_3-143562-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_3-193767-A-47.wav (# 144)
# 	Splitting "offs05_3-193767-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_4-161099-A-47.wav (# 145)
# 	Splitting "offs05_4-161099-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_4-161099-B-47.wav (# 146)
# 	Splitting "offs05_4-161099-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_4-161100-A-47.wav (# 147)
# 	Splitting "offs05_4-161100-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_4-161103-A-47.wav (# 148)
# 	Splitting "offs05_4-161103-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_4-161105-A-47.wav (# 149)
# 	Splitting "offs05_4-161105-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_4-161105-B-47.wav (# 150)
# 	Splitting "offs05_4-161105-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_4-251959-A-47.wav (# 151)
# 	Splitting "offs05_4-251959-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_4-255371-A-47.wav (# 152)
# 	Splitting "offs05_4-255371-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_5-215445-A-47.wav (# 153)
# 	Splitting "offs05_5-215445-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_5-215447-A-47.wav (# 154)
# 	Splitting "offs05_5-215447-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_5-215449-A-47.wav (# 155)
# 	Splitting "offs05_5-215449-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_5-235956-A-47.wav (# 156)
# 	Splitting "offs05_5-235956-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_5-251957-A-47.wav (# 157)
# 	Splitting "offs05_5-251957-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_5-251962-A-47.wav (# 158)
# 	Splitting "offs05_5-251962-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_5-251963-A-47.wav (# 159)
# 	Splitting "offs05_5-251963-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs05_5-251971-A-47.wav (# 160)
# 	Splitting "offs05_5-251971-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_1-11687-A-47.wav (# 161)
# 	Splitting "offs075_1-11687-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_1-24796-A-47.wav (# 162)
# 	Splitting "offs075_1-24796-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_1-36929-A-47.wav (# 163)
# 	Splitting "offs075_1-36929-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_1-43807-A-47.wav (# 164)
# 	Splitting "offs075_1-43807-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_1-43807-B-47.wav (# 165)
# 	Splitting "offs075_1-43807-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_1-43807-C-47.wav (# 166)
# 	Splitting "offs075_1-43807-C-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_1-43807-D-47.wav (# 167)
# 	Splitting "offs075_1-43807-D-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_1-53467-A-47.wav (# 168)
# 	Splitting "offs075_1-53467-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_2-105270-A-47.wav (# 169)
# 	Splitting "offs075_2-105270-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_2-106849-A-47.wav (# 170)
# 	Splitting "offs075_2-106849-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_2-160888-A-47.wav (# 171)
# 	Splitting "offs075_2-160888-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_2-74361-A-47.wav (# 172)
# 	Splitting "offs075_2-74361-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_2-78781-A-47.wav (# 173)
# 	Splitting "offs075_2-78781-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_2-78799-A-47.wav (# 174)
# 	Splitting "offs075_2-78799-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_2-96654-A-47.wav (# 175)
# 	Splitting "offs075_2-96654-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_2-98866-A-47.wav (# 176)
# 	Splitting "offs075_2-98866-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_3-115387-A-47.wav (# 177)
# 	Splitting "offs075_3-115387-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_3-115387-B-47.wav (# 178)
# 	Splitting "offs075_3-115387-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_3-115387-C-47.wav (# 179)
# 	Splitting "offs075_3-115387-C-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_3-128512-A-47.wav (# 180)
# 	Splitting "offs075_3-128512-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_3-128512-B-47.wav (# 181)
# 	Splitting "offs075_3-128512-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_3-143560-A-47.wav (# 182)
# 	Splitting "offs075_3-143560-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_3-143562-A-47.wav (# 183)
# 	Splitting "offs075_3-143562-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_3-193767-A-47.wav (# 184)
# 	Splitting "offs075_3-193767-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_4-161099-A-47.wav (# 185)
# 	Splitting "offs075_4-161099-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_4-161099-B-47.wav (# 186)
# 	Splitting "offs075_4-161099-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_4-161100-A-47.wav (# 187)
# 	Splitting "offs075_4-161100-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_4-161103-A-47.wav (# 188)
# 	Splitting "offs075_4-161103-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_4-161105-A-47.wav (# 189)
# 	Splitting "offs075_4-161105-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_4-161105-B-47.wav (# 190)
# 	Splitting "offs075_4-161105-B-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_4-251959-A-47.wav (# 191)
# 	Splitting "offs075_4-251959-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_4-255371-A-47.wav (# 192)
# 	Splitting "offs075_4-255371-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_5-215445-A-47.wav (# 193)
# 	Splitting "offs075_5-215445-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_5-215447-A-47.wav (# 194)
# 	Splitting "offs075_5-215447-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_5-215449-A-47.wav (# 195)
# 	Splitting "offs075_5-215449-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_5-235956-A-47.wav (# 196)
# 	Splitting "offs075_5-235956-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_5-251957-A-47.wav (# 197)
# 	Splitting "offs075_5-251957-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_5-251962-A-47.wav (# 198)
# 	Splitting "offs075_5-251962-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_5-251963-A-47.wav (# 199)
# 	Splitting "offs075_5-251963-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from offs075_5-251971-A-47.wav (# 200)
# 	Splitting "offs075_5-251971-A-47.wav" into 4 1-second part(s)
# Currently extracting features in "airplane" from psd1_1-11687-A-47.wav (# 201)
# 	Splitting "psd1_1-11687-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_1-24796-A-47.wav (# 202)
# 	Splitting "psd1_1-24796-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_1-36929-A-47.wav (# 203)
# 	Splitting "psd1_1-36929-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_1-43807-A-47.wav (# 204)
# 	Splitting "psd1_1-43807-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_1-43807-B-47.wav (# 205)
# 	Splitting "psd1_1-43807-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_1-43807-C-47.wav (# 206)
# 	Splitting "psd1_1-43807-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_1-43807-D-47.wav (# 207)
# 	Splitting "psd1_1-43807-D-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_1-53467-A-47.wav (# 208)
# 	Splitting "psd1_1-53467-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_2-105270-A-47.wav (# 209)
# 	Splitting "psd1_2-105270-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_2-106849-A-47.wav (# 210)
# 	Splitting "psd1_2-106849-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_2-160888-A-47.wav (# 211)
# 	Splitting "psd1_2-160888-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_2-74361-A-47.wav (# 212)
# 	Splitting "psd1_2-74361-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_2-78781-A-47.wav (# 213)
# 	Splitting "psd1_2-78781-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_2-78799-A-47.wav (# 214)
# 	Splitting "psd1_2-78799-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_2-96654-A-47.wav (# 215)
# 	Splitting "psd1_2-96654-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_2-98866-A-47.wav (# 216)
# 	Splitting "psd1_2-98866-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_3-115387-A-47.wav (# 217)
# 	Splitting "psd1_3-115387-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_3-115387-B-47.wav (# 218)
# 	Splitting "psd1_3-115387-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_3-115387-C-47.wav (# 219)
# 	Splitting "psd1_3-115387-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_3-128512-A-47.wav (# 220)
# 	Splitting "psd1_3-128512-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_3-128512-B-47.wav (# 221)
# 	Splitting "psd1_3-128512-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_3-143560-A-47.wav (# 222)
# 	Splitting "psd1_3-143560-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_3-143562-A-47.wav (# 223)
# 	Splitting "psd1_3-143562-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_3-193767-A-47.wav (# 224)
# 	Splitting "psd1_3-193767-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_4-161099-A-47.wav (# 225)
# 	Splitting "psd1_4-161099-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_4-161099-B-47.wav (# 226)
# 	Splitting "psd1_4-161099-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_4-161100-A-47.wav (# 227)
# 	Splitting "psd1_4-161100-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_4-161103-A-47.wav (# 228)
# 	Splitting "psd1_4-161103-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_4-161105-A-47.wav (# 229)
# 	Splitting "psd1_4-161105-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_4-161105-B-47.wav (# 230)
# 	Splitting "psd1_4-161105-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_4-251959-A-47.wav (# 231)
# 	Splitting "psd1_4-251959-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_4-255371-A-47.wav (# 232)
# 	Splitting "psd1_4-255371-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_5-215445-A-47.wav (# 233)
# 	Splitting "psd1_5-215445-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_5-215447-A-47.wav (# 234)
# 	Splitting "psd1_5-215447-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_5-215449-A-47.wav (# 235)
# 	Splitting "psd1_5-215449-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_5-235956-A-47.wav (# 236)
# 	Splitting "psd1_5-235956-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_5-251957-A-47.wav (# 237)
# 	Splitting "psd1_5-251957-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_5-251962-A-47.wav (# 238)
# 	Splitting "psd1_5-251962-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_5-251963-A-47.wav (# 239)
# 	Splitting "psd1_5-251963-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd1_5-251971-A-47.wav (# 240)
# 	Splitting "psd1_5-251971-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_1-11687-A-47.wav (# 241)
# 	Splitting "psd2_1-11687-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_1-24796-A-47.wav (# 242)
# 	Splitting "psd2_1-24796-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_1-36929-A-47.wav (# 243)
# 	Splitting "psd2_1-36929-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_1-43807-A-47.wav (# 244)
# 	Splitting "psd2_1-43807-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_1-43807-B-47.wav (# 245)
# 	Splitting "psd2_1-43807-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_1-43807-C-47.wav (# 246)
# 	Splitting "psd2_1-43807-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_1-43807-D-47.wav (# 247)
# 	Splitting "psd2_1-43807-D-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_1-53467-A-47.wav (# 248)
# 	Splitting "psd2_1-53467-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_2-105270-A-47.wav (# 249)
# 	Splitting "psd2_2-105270-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_2-106849-A-47.wav (# 250)
# 	Splitting "psd2_2-106849-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_2-160888-A-47.wav (# 251)
# 	Splitting "psd2_2-160888-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_2-74361-A-47.wav (# 252)
# 	Splitting "psd2_2-74361-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_2-78781-A-47.wav (# 253)
# 	Splitting "psd2_2-78781-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_2-78799-A-47.wav (# 254)
# 	Splitting "psd2_2-78799-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_2-96654-A-47.wav (# 255)
# 	Splitting "psd2_2-96654-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_2-98866-A-47.wav (# 256)
# 	Splitting "psd2_2-98866-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_3-115387-A-47.wav (# 257)
# 	Splitting "psd2_3-115387-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_3-115387-B-47.wav (# 258)
# 	Splitting "psd2_3-115387-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_3-115387-C-47.wav (# 259)
# 	Splitting "psd2_3-115387-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_3-128512-A-47.wav (# 260)
# 	Splitting "psd2_3-128512-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_3-128512-B-47.wav (# 261)
# 	Splitting "psd2_3-128512-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_3-143560-A-47.wav (# 262)
# 	Splitting "psd2_3-143560-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_3-143562-A-47.wav (# 263)
# 	Splitting "psd2_3-143562-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_3-193767-A-47.wav (# 264)
# 	Splitting "psd2_3-193767-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_4-161099-A-47.wav (# 265)
# 	Splitting "psd2_4-161099-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_4-161099-B-47.wav (# 266)
# 	Splitting "psd2_4-161099-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_4-161100-A-47.wav (# 267)
# 	Splitting "psd2_4-161100-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_4-161103-A-47.wav (# 268)
# 	Splitting "psd2_4-161103-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_4-161105-A-47.wav (# 269)
# 	Splitting "psd2_4-161105-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_4-161105-B-47.wav (# 270)
# 	Splitting "psd2_4-161105-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_4-251959-A-47.wav (# 271)
# 	Splitting "psd2_4-251959-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_4-255371-A-47.wav (# 272)
# 	Splitting "psd2_4-255371-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_5-215445-A-47.wav (# 273)
# 	Splitting "psd2_5-215445-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_5-215447-A-47.wav (# 274)
# 	Splitting "psd2_5-215447-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_5-215449-A-47.wav (# 275)
# 	Splitting "psd2_5-215449-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_5-235956-A-47.wav (# 276)
# 	Splitting "psd2_5-235956-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_5-251957-A-47.wav (# 277)
# 	Splitting "psd2_5-251957-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_5-251962-A-47.wav (# 278)
# 	Splitting "psd2_5-251962-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_5-251963-A-47.wav (# 279)
# 	Splitting "psd2_5-251963-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psd2_5-251971-A-47.wav (# 280)
# 	Splitting "psd2_5-251971-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_1-11687-A-47.wav (# 281)
# 	Splitting "psu1_1-11687-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_1-24796-A-47.wav (# 282)
# 	Splitting "psu1_1-24796-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_1-36929-A-47.wav (# 283)
# 	Splitting "psu1_1-36929-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_1-43807-A-47.wav (# 284)
# 	Splitting "psu1_1-43807-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_1-43807-B-47.wav (# 285)
# 	Splitting "psu1_1-43807-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_1-43807-C-47.wav (# 286)
# 	Splitting "psu1_1-43807-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_1-43807-D-47.wav (# 287)
# 	Splitting "psu1_1-43807-D-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_1-53467-A-47.wav (# 288)
# 	Splitting "psu1_1-53467-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_2-105270-A-47.wav (# 289)
# 	Splitting "psu1_2-105270-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_2-106849-A-47.wav (# 290)
# 	Splitting "psu1_2-106849-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_2-160888-A-47.wav (# 291)
# 	Splitting "psu1_2-160888-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_2-74361-A-47.wav (# 292)
# 	Splitting "psu1_2-74361-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_2-78781-A-47.wav (# 293)
# 	Splitting "psu1_2-78781-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_2-78799-A-47.wav (# 294)
# 	Splitting "psu1_2-78799-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_2-96654-A-47.wav (# 295)
# 	Splitting "psu1_2-96654-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_2-98866-A-47.wav (# 296)
# 	Splitting "psu1_2-98866-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_3-115387-A-47.wav (# 297)
# 	Splitting "psu1_3-115387-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_3-115387-B-47.wav (# 298)
# 	Splitting "psu1_3-115387-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_3-115387-C-47.wav (# 299)
# 	Splitting "psu1_3-115387-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_3-128512-A-47.wav (# 300)
# 	Splitting "psu1_3-128512-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_3-128512-B-47.wav (# 301)
# 	Splitting "psu1_3-128512-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_3-143560-A-47.wav (# 302)
# 	Splitting "psu1_3-143560-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_3-143562-A-47.wav (# 303)
# 	Splitting "psu1_3-143562-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_3-193767-A-47.wav (# 304)
# 	Splitting "psu1_3-193767-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_4-161099-A-47.wav (# 305)
# 	Splitting "psu1_4-161099-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_4-161099-B-47.wav (# 306)
# 	Splitting "psu1_4-161099-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_4-161100-A-47.wav (# 307)
# 	Splitting "psu1_4-161100-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_4-161103-A-47.wav (# 308)
# 	Splitting "psu1_4-161103-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_4-161105-A-47.wav (# 309)
# 	Splitting "psu1_4-161105-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_4-161105-B-47.wav (# 310)
# 	Splitting "psu1_4-161105-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_4-251959-A-47.wav (# 311)
# 	Splitting "psu1_4-251959-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_4-255371-A-47.wav (# 312)
# 	Splitting "psu1_4-255371-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_5-215445-A-47.wav (# 313)
# 	Splitting "psu1_5-215445-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_5-215447-A-47.wav (# 314)
# 	Splitting "psu1_5-215447-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_5-215449-A-47.wav (# 315)
# 	Splitting "psu1_5-215449-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_5-235956-A-47.wav (# 316)
# 	Splitting "psu1_5-235956-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_5-251957-A-47.wav (# 317)
# 	Splitting "psu1_5-251957-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_5-251962-A-47.wav (# 318)
# 	Splitting "psu1_5-251962-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_5-251963-A-47.wav (# 319)
# 	Splitting "psu1_5-251963-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu1_5-251971-A-47.wav (# 320)
# 	Splitting "psu1_5-251971-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_1-11687-A-47.wav (# 321)
# 	Splitting "psu2_1-11687-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_1-24796-A-47.wav (# 322)
# 	Splitting "psu2_1-24796-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_1-36929-A-47.wav (# 323)
# 	Splitting "psu2_1-36929-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_1-43807-A-47.wav (# 324)
# 	Splitting "psu2_1-43807-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_1-43807-B-47.wav (# 325)
# 	Splitting "psu2_1-43807-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_1-43807-C-47.wav (# 326)
# 	Splitting "psu2_1-43807-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_1-43807-D-47.wav (# 327)
# 	Splitting "psu2_1-43807-D-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_1-53467-A-47.wav (# 328)
# 	Splitting "psu2_1-53467-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_2-105270-A-47.wav (# 329)
# 	Splitting "psu2_2-105270-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_2-106849-A-47.wav (# 330)
# 	Splitting "psu2_2-106849-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_2-160888-A-47.wav (# 331)
# 	Splitting "psu2_2-160888-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_2-74361-A-47.wav (# 332)
# 	Splitting "psu2_2-74361-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_2-78781-A-47.wav (# 333)
# 	Splitting "psu2_2-78781-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_2-78799-A-47.wav (# 334)
# 	Splitting "psu2_2-78799-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_2-96654-A-47.wav (# 335)
# 	Splitting "psu2_2-96654-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_2-98866-A-47.wav (# 336)
# 	Splitting "psu2_2-98866-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_3-115387-A-47.wav (# 337)
# 	Splitting "psu2_3-115387-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_3-115387-B-47.wav (# 338)
# 	Splitting "psu2_3-115387-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_3-115387-C-47.wav (# 339)
# 	Splitting "psu2_3-115387-C-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_3-128512-A-47.wav (# 340)
# 	Splitting "psu2_3-128512-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_3-128512-B-47.wav (# 341)
# 	Splitting "psu2_3-128512-B-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_3-143560-A-47.wav (# 342)
# 	Splitting "psu2_3-143560-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_3-143562-A-47.wav (# 343)
# 	Splitting "psu2_3-143562-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_3-193767-A-47.wav (# 344)
# 	Splitting "psu2_3-193767-A-47.wav" into 5 1-second part(s)
# Currently extracting features in "airplane" from psu2_4-161099-A-47.wav (# 345)
# 	Splitting "psu2_4-161099-A-47.wav" into 5 1-second part(s)
# ...
# 	Splitting "ts2_1-54065-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_1-62509-A-45.wav (# 404)
# 	Splitting "ts2_1-62509-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_1-64473-A-45.wav (# 405)
# 	Splitting "ts2_1-64473-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_1-70300-A-45.wav (# 406)
# 	Splitting "ts2_1-70300-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_1-88409-A-45.wav (# 407)
# 	Splitting "ts2_1-88409-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_1-88409-B-45.wav (# 408)
# 	Splitting "ts2_1-88409-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_2-122066-A-45.wav (# 409)
# 	Splitting "ts2_2-122066-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_2-122066-B-45.wav (# 410)
# 	Splitting "ts2_2-122066-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_2-122067-A-45.wav (# 411)
# 	Splitting "ts2_2-122067-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_2-122067-B-45.wav (# 412)
# 	Splitting "ts2_2-122067-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_2-135649-A-45.wav (# 413)
# 	Splitting "ts2_2-135649-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_2-135649-B-45.wav (# 414)
# 	Splitting "ts2_2-135649-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_2-135649-C-45.wav (# 415)
# 	Splitting "ts2_2-135649-C-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_2-262579-A-45.wav (# 416)
# 	Splitting "ts2_2-262579-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_3-135650-A-45.wav (# 417)
# 	Splitting "ts2_3-135650-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_3-135650-B-45.wav (# 418)
# 	Splitting "ts2_3-135650-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_3-136451-A-45.wav (# 419)
# 	Splitting "ts2_3-136451-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_3-138212-A-45.wav (# 420)
# 	Splitting "ts2_3-138212-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_3-141559-A-45.wav (# 421)
# 	Splitting "ts2_3-141559-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_3-157492-A-45.wav (# 422)
# 	Splitting "ts2_3-157492-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_3-159445-A-45.wav (# 423)
# 	Splitting "ts2_3-159445-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_3-159445-B-45.wav (# 424)
# 	Splitting "ts2_3-159445-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_4-165606-A-45.wav (# 425)
# 	Splitting "ts2_4-165606-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_4-165791-A-45.wav (# 426)
# 	Splitting "ts2_4-165791-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_4-165791-B-45.wav (# 427)
# 	Splitting "ts2_4-165791-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_4-165845-A-45.wav (# 428)
# 	Splitting "ts2_4-165845-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_4-165845-B-45.wav (# 429)
# 	Splitting "ts2_4-165845-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_4-165933-A-45.wav (# 430)
# 	Splitting "ts2_4-165933-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_4-168446-A-45.wav (# 431)
# 	Splitting "ts2_4-168446-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_4-178881-A-45.wav (# 432)
# 	Splitting "ts2_4-178881-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_5-188796-A-45.wav (# 433)
# 	Splitting "ts2_5-188796-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_5-188945-A-45.wav (# 434)
# 	Splitting "ts2_5-188945-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_5-197118-A-45.wav (# 435)
# 	Splitting "ts2_5-197118-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_5-197121-A-45.wav (# 436)
# 	Splitting "ts2_5-197121-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_5-197121-B-45.wav (# 437)
# 	Splitting "ts2_5-197121-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_5-198600-A-45.wav (# 438)
# 	Splitting "ts2_5-198600-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_5-199284-A-45.wav (# 439)
# 	Splitting "ts2_5-199284-A-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts2_5-199284-B-45.wav (# 440)
# 	Splitting "ts2_5-199284-B-45.wav" into 5 1-second part(s)
# Currently extracting features in "train" from ts3_1-119125-A-45.wav (# 441)
# 	Splitting "ts3_1-119125-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_1-54065-A-45.wav (# 442)
# 	Splitting "ts3_1-54065-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_1-54065-B-45.wav (# 443)
# 	Splitting "ts3_1-54065-B-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_1-62509-A-45.wav (# 444)
# 	Splitting "ts3_1-62509-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_1-64473-A-45.wav (# 445)
# 	Splitting "ts3_1-64473-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_1-70300-A-45.wav (# 446)
# 	Splitting "ts3_1-70300-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_1-88409-A-45.wav (# 447)
# 	Splitting "ts3_1-88409-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_1-88409-B-45.wav (# 448)
# 	Splitting "ts3_1-88409-B-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_2-122066-A-45.wav (# 449)
# 	Splitting "ts3_2-122066-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_2-122066-B-45.wav (# 450)
# 	Splitting "ts3_2-122066-B-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_2-122067-A-45.wav (# 451)
# 	Splitting "ts3_2-122067-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_2-122067-B-45.wav (# 452)
# 	Splitting "ts3_2-122067-B-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_2-135649-A-45.wav (# 453)
# 	Splitting "ts3_2-135649-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_2-135649-B-45.wav (# 454)
# 	Splitting "ts3_2-135649-B-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_2-135649-C-45.wav (# 455)
# 	Splitting "ts3_2-135649-C-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_2-262579-A-45.wav (# 456)
# 	Splitting "ts3_2-262579-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_3-135650-A-45.wav (# 457)
# 	Splitting "ts3_3-135650-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_3-135650-B-45.wav (# 458)
# 	Splitting "ts3_3-135650-B-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_3-136451-A-45.wav (# 459)
# 	Splitting "ts3_3-136451-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_3-138212-A-45.wav (# 460)
# 	Splitting "ts3_3-138212-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_3-141559-A-45.wav (# 461)
# 	Splitting "ts3_3-141559-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_3-157492-A-45.wav (# 462)
# 	Splitting "ts3_3-157492-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_3-159445-A-45.wav (# 463)
# 	Splitting "ts3_3-159445-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_3-159445-B-45.wav (# 464)
# 	Splitting "ts3_3-159445-B-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_4-165606-A-45.wav (# 465)
# 	Splitting "ts3_4-165606-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_4-165791-A-45.wav (# 466)
# 	Splitting "ts3_4-165791-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_4-165791-B-45.wav (# 467)
# 	Splitting "ts3_4-165791-B-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_4-165845-A-45.wav (# 468)
# 	Splitting "ts3_4-165845-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_4-165845-B-45.wav (# 469)
# 	Splitting "ts3_4-165845-B-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_4-165933-A-45.wav (# 470)
# 	Splitting "ts3_4-165933-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_4-168446-A-45.wav (# 471)
# 	Splitting "ts3_4-168446-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_4-178881-A-45.wav (# 472)
# 	Splitting "ts3_4-178881-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_5-188796-A-45.wav (# 473)
# 	Splitting "ts3_5-188796-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_5-188945-A-45.wav (# 474)
# 	Splitting "ts3_5-188945-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_5-197118-A-45.wav (# 475)
# 	Splitting "ts3_5-197118-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_5-197121-A-45.wav (# 476)
# 	Splitting "ts3_5-197121-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_5-197121-B-45.wav (# 477)
# 	Splitting "ts3_5-197121-B-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_5-198600-A-45.wav (# 478)
# 	Splitting "ts3_5-198600-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_5-199284-A-45.wav (# 479)
# 	Splitting "ts3_5-199284-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts3_5-199284-B-45.wav (# 480)
# 	Splitting "ts3_5-199284-B-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_1-119125-A-45.wav (# 481)
# 	Splitting "ts4_1-119125-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_1-54065-A-45.wav (# 482)
# 	Splitting "ts4_1-54065-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_1-54065-B-45.wav (# 483)
# 	Splitting "ts4_1-54065-B-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_1-62509-A-45.wav (# 484)
# 	Splitting "ts4_1-62509-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_1-64473-A-45.wav (# 485)
# 	Splitting "ts4_1-64473-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_1-70300-A-45.wav (# 486)
# 	Splitting "ts4_1-70300-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_1-88409-A-45.wav (# 487)
# 	Splitting "ts4_1-88409-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_1-88409-B-45.wav (# 488)
# 	Splitting "ts4_1-88409-B-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_2-122066-A-45.wav (# 489)
# 	Splitting "ts4_2-122066-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_2-122066-B-45.wav (# 490)
# 	Splitting "ts4_2-122066-B-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_2-122067-A-45.wav (# 491)
# 	Splitting "ts4_2-122067-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_2-122067-B-45.wav (# 492)
# 	Splitting "ts4_2-122067-B-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_2-135649-A-45.wav (# 493)
# 	Splitting "ts4_2-135649-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_2-135649-B-45.wav (# 494)
# 	Splitting "ts4_2-135649-B-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_2-135649-C-45.wav (# 495)
# 	Splitting "ts4_2-135649-C-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_2-262579-A-45.wav (# 496)
# 	Splitting "ts4_2-262579-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_3-135650-A-45.wav (# 497)
# 	Splitting "ts4_3-135650-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_3-135650-B-45.wav (# 498)
# 	Splitting "ts4_3-135650-B-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_3-136451-A-45.wav (# 499)
# 	Splitting "ts4_3-136451-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_3-138212-A-45.wav (# 500)
# 	Splitting "ts4_3-138212-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_3-141559-A-45.wav (# 501)
# 	Splitting "ts4_3-141559-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_3-157492-A-45.wav (# 502)
# 	Splitting "ts4_3-157492-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_3-159445-A-45.wav (# 503)
# 	Splitting "ts4_3-159445-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_3-159445-B-45.wav (# 504)
# 	Splitting "ts4_3-159445-B-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_4-165606-A-45.wav (# 505)
# 	Splitting "ts4_4-165606-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_4-165791-A-45.wav (# 506)
# 	Splitting "ts4_4-165791-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_4-165791-B-45.wav (# 507)
# 	Splitting "ts4_4-165791-B-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_4-165845-A-45.wav (# 508)
# 	Splitting "ts4_4-165845-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_4-165845-B-45.wav (# 509)
# 	Splitting "ts4_4-165845-B-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_4-165933-A-45.wav (# 510)
# 	Splitting "ts4_4-165933-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_4-168446-A-45.wav (# 511)
# 	Splitting "ts4_4-168446-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_4-178881-A-45.wav (# 512)
# 	Splitting "ts4_4-178881-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_5-188796-A-45.wav (# 513)
# 	Splitting "ts4_5-188796-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_5-188945-A-45.wav (# 514)
# 	Splitting "ts4_5-188945-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_5-197118-A-45.wav (# 515)
# 	Splitting "ts4_5-197118-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_5-197121-A-45.wav (# 516)
# 	Splitting "ts4_5-197121-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_5-197121-B-45.wav (# 517)
# 	Splitting "ts4_5-197121-B-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_5-198600-A-45.wav (# 518)
# 	Splitting "ts4_5-198600-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_5-199284-A-45.wav (# 519)
# 	Splitting "ts4_5-199284-A-45.wav" into 4 1-second part(s)
# Currently extracting features in "train" from ts4_5-199284-B-45.wav (# 520)
# 	Splitting "ts4_5-199284-B-45.wav" into 4 1-second part(s)
# ----- done. -----
# Total file count: 2605
# Files ignored: 0
# Extracted 12200 windows from 2605 Files
# Shape of dataframe: (12200, 25, 28)
# Shape of labels: (12200,)
# Shape of LEQs: (12200,)

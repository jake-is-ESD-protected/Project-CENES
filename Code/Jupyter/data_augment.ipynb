# %%
# needed imports
import IPython.display as ipd
import augmolino.augmolino.augmentation as aug

# %%
path = 'Datasets/UrbanSound8k/audio/fold1/'
f_name = '7061-6-0-0.wav'
fp = path + f_name
fp_new = 'augmented_data/' + 'augm_' + f_name
print(fp_new)

fp_new = aug.fuseAudio(fp, "water-rain3.wav", fp_new, 0.5)
aug.spectrogram(fp_new)

ipd.Audio(fp_new)
# Out:
# augmented_data/augm_7061-6-0-0.wav
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
